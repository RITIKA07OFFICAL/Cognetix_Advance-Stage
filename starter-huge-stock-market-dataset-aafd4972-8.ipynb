# %% [markdown]
# ## Introduction
# Greetings from the Kaggle bot! This is an automatically-generated kernel with starter code demonstrating how to read in the data and begin exploring. Click the blue "Edit Notebook" or "Fork Notebook" button at the top of this kernel to begin editing.

# %% [markdown]
# ## Exploratory Analysis
# To begin this exploratory analysis, first use `matplotlib` to import libraries and define functions for plotting the data. Depending on the data, not all plots will be made. (Hey, I'm just a kerneling bot, not a Kaggle Competitions Grandmaster!)

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# There is 0 csv file in the current version of the dataset:

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/Data/ETFs/xlb.us.txt
# /kaggle/input/Data/ETFs/fdl.us.txt
# /kaggle/input/Data/ETFs/qmn.us.txt
# /kaggle/input/Data/ETFs/ftlb.us.txt
# /kaggle/input/Data/ETFs/sil.us.txt
# /kaggle/input/Data/ETFs/gbf.us.txt
# /kaggle/input/Data/ETFs/cper.us.txt
# /kaggle/input/Data/ETFs/jnug.us.txt
# /kaggle/input/Data/ETFs/zsl.us.txt
# /kaggle/input/Data/ETFs/qemm.us.txt
# /kaggle/input/Data/ETFs/rola.us.txt
# /kaggle/input/Data/ETFs/lstk.us.txt
# /kaggle/input/Data/ETFs/pxj.us.txt
# /kaggle/input/Data/ETFs/lit.us.txt
# /kaggle/input/Data/ETFs/sgdm.us.txt
# /kaggle/input/Data/ETFs/fas.us.txt
# /kaggle/input/Data/ETFs/qls.us.txt
# /kaggle/input/Data/ETFs/qlta.us.txt
# /kaggle/input/Data/ETFs/fyld.us.txt
# /kaggle/input/Data/ETFs/kbe.us.txt
# /kaggle/input/Data/ETFs/econ.us.txt
# /kaggle/input/Data/ETFs/hdv.us.txt
# /kaggle/input/Data/ETFs/vtwo.us.txt
# /kaggle/input/Data/ETFs/egpt.us.txt
# /kaggle/input/Data/ETFs/ief.us.txt
# /kaggle/input/Data/ETFs/weat.us.txt
# /kaggle/input/Data/ETFs/rzg.us.txt
# /kaggle/input/Data/ETFs/ijr.us.txt
# /kaggle/input/Data/ETFs/ibdo.us.txt
# /kaggle/input/Data/ETFs/qual.us.txt
# /kaggle/input/Data/ETFs/gvi.us.txt
# /kaggle/input/Data/ETFs/pbw.us.txt
# /kaggle/input/Data/ETFs/tipx.us.txt
# /kaggle/input/Data/ETFs/btal.us.txt
# /kaggle/input/Data/ETFs/soxs.us.txt
# /kaggle/input/Data/ETFs/kroo.us.txt
# /kaggle/input/Data/ETFs/dbo.us.txt
# /kaggle/input/Data/ETFs/ayt.us.txt
# /kaggle/input/Data/ETFs/midz.us.txt
# /kaggle/input/Data/ETFs/rusl.us.txt
# /kaggle/input/Data/ETFs/iyh.us.txt
# /kaggle/input/Data/ETFs/bib.us.txt
# /kaggle/input/Data/ETFs/fidu.us.txt
# /kaggle/input/Data/ETFs/umdd.us.txt
# /kaggle/input/Data/ETFs/gyld.us.txt
# /kaggle/input/Data/ETFs/ibdb.us.txt
# /kaggle/input/Data/ETFs/vt.us.txt
# /kaggle/input/Data/ETFs/lmbs.us.txt
# /kaggle/input/Data/ETFs/vo.us.txt
# /kaggle/input/Data/ETFs/vlu.us.txt
# /kaggle/input/Data/ETFs/qid.us.txt
# /kaggle/input/Data/ETFs/tna.us.txt
# /kaggle/input/Data/ETFs/pxlv.us.txt
# /kaggle/input/Data/ETFs/jkl.us.txt
# /kaggle/input/Data/ETFs/tolz.us.txt
# /kaggle/input/Data/ETFs/fpl.us.txt
# /kaggle/input/Data/ETFs/itot.us.txt
# /kaggle/input/Data/ETFs/ixn.us.txt
# /kaggle/input/Data/ETFs/ige.us.txt
# /kaggle/input/Data/ETFs/eww.us.txt
# /kaggle/input/Data/ETFs/dgt.us.txt
# /kaggle/input/Data/ETFs/hold.us.txt
# /kaggle/input/Data/ETFs/eql.us.txt
# /kaggle/input/Data/ETFs/foil.us.txt
# /kaggle/input/Data/ETFs/rsx.us.txt
# /kaggle/input/Data/ETFs/fone.us.txt
# /kaggle/input/Data/ETFs/emsh.us.txt
# /kaggle/input/Data/ETFs/tusa.us.txt
# /kaggle/input/Data/ETFs/dbem.us.txt
# /kaggle/input/Data/ETFs/ewn.us.txt
# /kaggle/input/Data/ETFs/jkd.us.txt
# /kaggle/input/Data/ETFs/xslv.us.txt
# /kaggle/input/Data/ETFs/vmbs.us.txt
# /kaggle/input/Data/ETFs/gru.us.txt
# /kaggle/input/Data/ETFs/gbb.us.txt
# /kaggle/input/Data/ETFs/idog.us.txt
# /kaggle/input/Data/ETFs/tdtf.us.txt
# /kaggle/input/Data/ETFs/fndc.us.txt
# /kaggle/input/Data/ETFs/ifv.us.txt
# /kaggle/input/Data/ETFs/ald.us.txt
# /kaggle/input/Data/ETFs/ftsl.us.txt
# /kaggle/input/Data/ETFs/pek.us.txt
# /kaggle/input/Data/ETFs/fgd.us.txt
# /kaggle/input/Data/ETFs/csd.us.txt
# /kaggle/input/Data/ETFs/geur.us.txt
# /kaggle/input/Data/ETFs/vgt.us.txt
# /kaggle/input/Data/ETFs/totl.us.txt
# /kaggle/input/Data/ETFs/eema.us.txt
# /kaggle/input/Data/ETFs/sjnk.us.txt
# /kaggle/input/Data/ETFs/fnde.us.txt
# /kaggle/input/Data/ETFs/plnd.us.txt
# /kaggle/input/Data/ETFs/iau.us.txt
# /kaggle/input/Data/ETFs/hymb.us.txt
# /kaggle/input/Data/ETFs/hewg.us.txt
# /kaggle/input/Data/ETFs/xtl.us.txt
# /kaggle/input/Data/ETFs/sye.us.txt
# /kaggle/input/Data/ETFs/soyb.us.txt
# /kaggle/input/Data/ETFs/kbwr.us.txt
# /kaggle/input/Data/ETFs/xhe.us.txt
# /kaggle/input/Data/ETFs/flge.us.txt
# /kaggle/input/Data/ETFs/bsco.us.txt
# /kaggle/input/Data/ETFs/fdts.us.txt
# /kaggle/input/Data/ETFs/flot.us.txt
# /kaggle/input/Data/ETFs/sdyl.us.txt
# /kaggle/input/Data/ETFs/xlp.us.txt
# /kaggle/input/Data/ETFs/enfr.us.txt
# /kaggle/input/Data/ETFs/urr.us.txt
# /kaggle/input/Data/ETFs/iusv.us.txt
# /kaggle/input/Data/ETFs/iws.us.txt
# /kaggle/input/Data/ETFs/iwp.us.txt
# /kaggle/input/Data/ETFs/remx.us.txt
# /kaggle/input/Data/ETFs/dxge.us.txt
# /kaggle/input/Data/ETFs/xiv.us.txt
# /kaggle/input/Data/ETFs/ita.us.txt
# /kaggle/input/Data/ETFs/ivw.us.txt
# /kaggle/input/Data/ETFs/smb.us.txt
# /kaggle/input/Data/ETFs/mub.us.txt
# /kaggle/input/Data/ETFs/nfo.us.txt
# /kaggle/input/Data/ETFs/bzf.us.txt
# /kaggle/input/Data/ETFs/dcng.us.txt
# /kaggle/input/Data/ETFs/bsci.us.txt
# /kaggle/input/Data/ETFs/ibnd.us.txt
# /kaggle/input/Data/ETFs/rxi.us.txt
# /kaggle/input/Data/ETFs/brzu.us.txt
# /kaggle/input/Data/ETFs/sbb.us.txt
# /kaggle/input/Data/ETFs/fxu.us.txt
# /kaggle/input/Data/ETFs/ewem.us.txt
# /kaggle/input/Data/ETFs/qed.us.txt
# /kaggle/input/Data/ETFs/psci.us.txt
# /kaggle/input/Data/ETFs/qefa.us.txt
# /kaggle/input/Data/ETFs/uhn.us.txt
# /kaggle/input/Data/ETFs/iqdy.us.txt
# /kaggle/input/Data/ETFs/ibdc.us.txt
# /kaggle/input/Data/ETFs/xt.us.txt
# /kaggle/input/Data/ETFs/viog.us.txt
# /kaggle/input/Data/ETFs/ewz.us.txt
# /kaggle/input/Data/ETFs/hyem.us.txt
# /kaggle/input/Data/ETFs/fmf.us.txt
# /kaggle/input/Data/ETFs/epu.us.txt
# /kaggle/input/Data/ETFs/pvi.us.txt
# /kaggle/input/Data/ETFs/usmv.us.txt
# /kaggle/input/Data/ETFs/ttt.us.txt
# /kaggle/input/Data/ETFs/lrgf.us.txt
# /kaggle/input/Data/ETFs/aoa.us.txt
# /kaggle/input/Data/ETFs/lqdh.us.txt
# /kaggle/input/Data/ETFs/igf.us.txt
# /kaggle/input/Data/ETFs/ewk.us.txt
# /kaggle/input/Data/ETFs/icol.us.txt
# /kaggle/input/Data/ETFs/rdvy.us.txt
# /kaggle/input/Data/ETFs/isra.us.txt
# /kaggle/input/Data/ETFs/rww.us.txt
# /kaggle/input/Data/ETFs/div.us.txt
# /kaggle/input/Data/ETFs/rom.us.txt
# /kaggle/input/Data/ETFs/urth.us.txt
# /kaggle/input/Data/ETFs/ure.us.txt
# /kaggle/input/Data/ETFs/cupm.us.txt
# /kaggle/input/Data/ETFs/comt.us.txt
# /kaggle/input/Data/ETFs/gce.us.txt
# /kaggle/input/Data/ETFs/slv.us.txt
# /kaggle/input/Data/ETFs/pzt.us.txt
# /kaggle/input/Data/ETFs/dgro.us.txt
# /kaggle/input/Data/ETFs/eusc.us.txt
# /kaggle/input/Data/ETFs/dbc.us.txt
# /kaggle/input/Data/ETFs/fxb.us.txt
# /kaggle/input/Data/ETFs/sef.us.txt
# /kaggle/input/Data/ETFs/rxd.us.txt
# /kaggle/input/Data/ETFs/epi.us.txt
# /kaggle/input/Data/ETFs/igm.us.txt
# /kaggle/input/Data/ETFs/regl.us.txt
# /kaggle/input/Data/ETFs/xpp.us.txt
# /kaggle/input/Data/ETFs/grid.us.txt
# /kaggle/input/Data/ETFs/ibdp.us.txt
# /kaggle/input/Data/ETFs/vtv.us.txt
# /kaggle/input/Data/ETFs/nini.us.txt
# /kaggle/input/Data/ETFs/gaz.us.txt
# /kaggle/input/Data/ETFs/bkln.us.txt
# /kaggle/input/Data/ETFs/ewt.us.txt
# /kaggle/input/Data/ETFs/sdog.us.txt
# /kaggle/input/Data/ETFs/udow.us.txt
# /kaggle/input/Data/ETFs/wdti.us.txt
# /kaggle/input/Data/ETFs/spxs.us.txt
# /kaggle/input/Data/ETFs/bsck.us.txt
# /kaggle/input/Data/ETFs/qdeu.us.txt
# /kaggle/input/Data/ETFs/pxmg.us.txt
# /kaggle/input/Data/ETFs/dgz.us.txt
# /kaggle/input/Data/ETFs/dsum.us.txt
# /kaggle/input/Data/ETFs/ugl.us.txt
# /kaggle/input/Data/ETFs/cvy.us.txt
# /kaggle/input/Data/ETFs/moo.us.txt
# /kaggle/input/Data/ETFs/bzq.us.txt
# /kaggle/input/Data/ETFs/agf.us.txt
# /kaggle/input/Data/ETFs/gsy.us.txt
# /kaggle/input/Data/ETFs/cntr.us.txt
# /kaggle/input/Data/ETFs/voo.us.txt
# /kaggle/input/Data/ETFs/fxr.us.txt
# /kaggle/input/Data/ETFs/dxjr.us.txt
# /kaggle/input/Data/ETFs/fpf.us.txt
# /kaggle/input/Data/ETFs/schp.us.txt
# /kaggle/input/Data/ETFs/ylco.us.txt
# /kaggle/input/Data/ETFs/usv.us.txt
# /kaggle/input/Data/ETFs/pin.us.txt
# /kaggle/input/Data/ETFs/pwv.us.txt
# /kaggle/input/Data/ETFs/govt.us.txt
# /kaggle/input/Data/ETFs/ftls.us.txt
# /kaggle/input/Data/ETFs/dxj.us.txt
# /kaggle/input/Data/ETFs/dgp.us.txt
# /kaggle/input/Data/ETFs/pxsg.us.txt
# /kaggle/input/Data/ETFs/bcm.us.txt
# /kaggle/input/Data/ETFs/socl.us.txt
# /kaggle/input/Data/ETFs/ldri.us.txt
# /kaggle/input/Data/ETFs/cmf.us.txt
# /kaggle/input/Data/ETFs/tza.us.txt
# /kaggle/input/Data/ETFs/tags.us.txt
# /kaggle/input/Data/ETFs/imtm.us.txt
# /kaggle/input/Data/ETFs/sea.us.txt
# /kaggle/input/Data/ETFs/fxn.us.txt
# /kaggle/input/Data/ETFs/uup.us.txt
# /kaggle/input/Data/ETFs/qqew.us.txt
# /kaggle/input/Data/ETFs/evx.us.txt
# /kaggle/input/Data/ETFs/bfor.us.txt
# /kaggle/input/Data/ETFs/ftgc.us.txt
# /kaggle/input/Data/ETFs/dxd.us.txt
# /kaggle/input/Data/ETFs/fcg.us.txt
# /kaggle/input/Data/ETFs/silj.us.txt
# /kaggle/input/Data/ETFs/gmom.us.txt
# /kaggle/input/Data/ETFs/sagg.us.txt
# /kaggle/input/Data/ETFs/ugld.us.txt
# /kaggle/input/Data/ETFs/ctnn.us.txt
# /kaggle/input/Data/ETFs/guru.us.txt
# /kaggle/input/Data/ETFs/vxx.us.txt
# /kaggle/input/Data/ETFs/tyo.us.txt
# /kaggle/input/Data/ETFs/kol.us.txt
# /kaggle/input/Data/ETFs/inxx.us.txt
# /kaggle/input/Data/ETFs/ddm.us.txt
# /kaggle/input/Data/ETFs/mdyg.us.txt
# /kaggle/input/Data/ETFs/psct.us.txt
# /kaggle/input/Data/ETFs/dem.us.txt
# /kaggle/input/Data/ETFs/thd.us.txt
# /kaggle/input/Data/ETFs/sgar.us.txt
# /kaggle/input/Data/ETFs/bjk.us.txt
# /kaggle/input/Data/ETFs/skf.us.txt
# /kaggle/input/Data/ETFs/stpz.us.txt
# /kaggle/input/Data/ETFs/gres.us.txt
# /kaggle/input/Data/ETFs/phb.us.txt
# /kaggle/input/Data/ETFs/ivoo.us.txt
# /kaggle/input/Data/ETFs/pie.us.txt
# /kaggle/input/Data/ETFs/yang.us.txt
# /kaggle/input/Data/ETFs/pbj.us.txt
# /kaggle/input/Data/ETFs/idu.us.txt
# /kaggle/input/Data/ETFs/prb.us.txt
# /kaggle/input/Data/ETFs/xlg.us.txt
# /kaggle/input/Data/ETFs/rly.us.txt
# /kaggle/input/Data/ETFs/bil.us.txt
# /kaggle/input/Data/ETFs/lmlp.us.txt
# /kaggle/input/Data/ETFs/figy.us.txt
# /kaggle/input/Data/ETFs/voov.us.txt
# /kaggle/input/Data/ETFs/uag.us.txt
# /kaggle/input/Data/ETFs/doo.us.txt
# /kaggle/input/Data/ETFs/ihi.us.txt
# /kaggle/input/Data/ETFs/splv.us.txt
# /kaggle/input/Data/ETFs/pex.us.txt
# /kaggle/input/Data/ETFs/ule.us.txt
# /kaggle/input/Data/ETFs/dbs.us.txt
# /kaggle/input/Data/ETFs/puw.us.txt
# /kaggle/input/Data/ETFs/eumv.us.txt
# /kaggle/input/Data/ETFs/eudg.us.txt
# /kaggle/input/Data/ETFs/gsc.us.txt
# /kaggle/input/Data/ETFs/eirl.us.txt
# /kaggle/input/Data/ETFs/iyk.us.txt
# /kaggle/input/Data/ETFs/frak.us.txt
# /kaggle/input/Data/ETFs/fgm.us.txt
# /kaggle/input/Data/ETFs/mlpx.us.txt
# /kaggle/input/Data/ETFs/ucc.us.txt
# /kaggle/input/Data/ETFs/ipff.us.txt
# /kaggle/input/Data/ETFs/shy.us.txt
# /kaggle/input/Data/ETFs/pscm.us.txt
# /kaggle/input/Data/ETFs/jjc.us.txt
# /kaggle/input/Data/ETFs/weet.us.txt
# /kaggle/input/Data/ETFs/psce.us.txt
# /kaggle/input/Data/ETFs/scij.us.txt
# /kaggle/input/Data/ETFs/fyc.us.txt
# /kaggle/input/Data/ETFs/tmv.us.txt
# /kaggle/input/Data/ETFs/iwx.us.txt
# /kaggle/input/Data/ETFs/xsoe.us.txt
# /kaggle/input/Data/ETFs/drr.us.txt
# /kaggle/input/Data/ETFs/ihdg.us.txt
# /kaggle/input/Data/ETFs/tao.us.txt
# /kaggle/input/Data/ETFs/pdn.us.txt
# /kaggle/input/Data/ETFs/iwr.us.txt
# /kaggle/input/Data/ETFs/dbe.us.txt
# /kaggle/input/Data/ETFs/schb.us.txt
# /kaggle/input/Data/ETFs/eqlt.us.txt
# /kaggle/input/Data/ETFs/djp.us.txt
# /kaggle/input/Data/ETFs/kce.us.txt
# /kaggle/input/Data/ETFs/gcc.us.txt
# /kaggle/input/Data/ETFs/iyt.us.txt
# /kaggle/input/Data/ETFs/spxl.us.txt
# /kaggle/input/Data/ETFs/scin.us.txt
# /kaggle/input/Data/ETFs/fpxi.us.txt
# /kaggle/input/Data/ETFs/gwx.us.txt
# /kaggle/input/Data/ETFs/dbmx.us.txt
# /kaggle/input/Data/ETFs/emcb.us.txt
# /kaggle/input/Data/ETFs/pej.us.txt
# /kaggle/input/Data/ETFs/cyb.us.txt
# /kaggle/input/Data/ETFs/iyr.us.txt
# /kaggle/input/Data/ETFs/ibln.us.txt
# /kaggle/input/Data/ETFs/iai.us.txt
# /kaggle/input/Data/ETFs/cnxt.us.txt
# /kaggle/input/Data/ETFs/ltpz.us.txt
# /kaggle/input/Data/ETFs/qdf.us.txt
# /kaggle/input/Data/ETFs/iyg.us.txt
# /kaggle/input/Data/ETFs/fmy.us.txt
# /kaggle/input/Data/ETFs/fue.us.txt
# /kaggle/input/Data/ETFs/uge.us.txt
# /kaggle/input/Data/ETFs/fud.us.txt
# /kaggle/input/Data/ETFs/oef.us.txt
# /kaggle/input/Data/ETFs/uae.us.txt
# /kaggle/input/Data/ETFs/slyv.us.txt
# /kaggle/input/Data/ETFs/bkf.us.txt
# /kaggle/input/Data/ETFs/dxjc.us.txt
# /kaggle/input/Data/ETFs/psch.us.txt
# /kaggle/input/Data/ETFs/gld.us.txt
# /kaggle/input/Data/ETFs/fxs.us.txt
# /kaggle/input/Data/ETFs/dyy.us.txt
# /kaggle/input/Data/ETFs/ttfs.us.txt
# /kaggle/input/Data/ETFs/bbp.us.txt
# /kaggle/input/Data/ETFs/hao.us.txt
# /kaggle/input/Data/ETFs/eev.us.txt
# /kaggle/input/Data/ETFs/aia.us.txt
# /kaggle/input/Data/ETFs/shyg.us.txt
# /kaggle/input/Data/ETFs/roof.us.txt
# /kaggle/input/Data/ETFs/mdy.us.txt
# /kaggle/input/Data/ETFs/vclt.us.txt
# /kaggle/input/Data/ETFs/cly.us.txt
# /kaggle/input/Data/ETFs/fm.us.txt
# /kaggle/input/Data/ETFs/ulst.us.txt
# /kaggle/input/Data/ETFs/ryf.us.txt
# /kaggle/input/Data/ETFs/ring.us.txt
# /kaggle/input/Data/ETFs/wmw.us.txt
# /kaggle/input/Data/ETFs/feu.us.txt
# /kaggle/input/Data/ETFs/hgi.us.txt
# /kaggle/input/Data/ETFs/igov.us.txt
# /kaggle/input/Data/ETFs/hyih.us.txt
# /kaggle/input/Data/ETFs/fxg.us.txt
# /kaggle/input/Data/ETFs/ltl.us.txt
# /kaggle/input/Data/ETFs/pkb.us.txt
# /kaggle/input/Data/ETFs/ubn.us.txt
# /kaggle/input/Data/ETFs/dslv.us.txt
# /kaggle/input/Data/ETFs/vht.us.txt
# /kaggle/input/Data/ETFs/angl.us.txt
# /kaggle/input/Data/ETFs/scid.us.txt
# /kaggle/input/Data/ETFs/eurl.us.txt
# /kaggle/input/Data/ETFs/vwob.us.txt
# /kaggle/input/Data/ETFs/prf.us.txt
# /kaggle/input/Data/ETFs/qyld.us.txt
# /kaggle/input/Data/ETFs/ashr.us.txt
# /kaggle/input/Data/ETFs/rji.us.txt
# /kaggle/input/Data/ETFs/lbj.us.txt
# /kaggle/input/Data/ETFs/smlv.us.txt
# /kaggle/input/Data/ETFs/usag.us.txt
# /kaggle/input/Data/ETFs/twm.us.txt
# /kaggle/input/Data/ETFs/fsz.us.txt
# /kaggle/input/Data/ETFs/rjz.us.txt
# /kaggle/input/Data/ETFs/sdiv.us.txt
# /kaggle/input/Data/ETFs/dgs.us.txt
# /kaggle/input/Data/ETFs/psr.us.txt
# /kaggle/input/Data/ETFs/yxi.us.txt
# /kaggle/input/Data/ETFs/amu.us.txt
# /kaggle/input/Data/ETFs/iyy.us.txt
# /kaggle/input/Data/ETFs/vfh.us.txt
# /kaggle/input/Data/ETFs/ibmg.us.txt
# /kaggle/input/Data/ETFs/aom.us.txt
# /kaggle/input/Data/ETFs/vnqi.us.txt
# /kaggle/input/Data/ETFs/mcro.us.txt
# /kaggle/input/Data/ETFs/vgit.us.txt
# /kaggle/input/Data/ETFs/lglv.us.txt
# /kaggle/input/Data/ETFs/lalt.us.txt
# /kaggle/input/Data/ETFs/lqd.us.txt
# /kaggle/input/Data/ETFs/rvnu.us.txt
# /kaggle/input/Data/ETFs/ryu.us.txt
# /kaggle/input/Data/ETFs/dtn.us.txt
# /kaggle/input/Data/ETFs/hdge.us.txt
# /kaggle/input/Data/ETFs/ause.us.txt
# /kaggle/input/Data/ETFs/schc.us.txt
# /kaggle/input/Data/ETFs/spyb.us.txt
# /kaggle/input/Data/ETFs/ubc.us.txt
# /kaggle/input/Data/ETFs/dgl.us.txt
# /kaggle/input/Data/ETFs/fxc.us.txt
# /kaggle/input/Data/ETFs/reet.us.txt
# /kaggle/input/Data/ETFs/iwv.us.txt
# /kaggle/input/Data/ETFs/fvl.us.txt
# /kaggle/input/Data/ETFs/gnr.us.txt
# /kaggle/input/Data/ETFs/dls.us.txt
# /kaggle/input/Data/ETFs/cbon.us.txt
# /kaggle/input/Data/ETFs/ymli.us.txt
# /kaggle/input/Data/ETFs/mom.us.txt
# /kaggle/input/Data/ETFs/dol.us.txt
# /kaggle/input/Data/ETFs/boil.us.txt
# /kaggle/input/Data/ETFs/eqal.us.txt
# /kaggle/input/Data/ETFs/vtwv.us.txt
# /kaggle/input/Data/ETFs/qcln.us.txt
# /kaggle/input/Data/ETFs/epp.us.txt
# /kaggle/input/Data/ETFs/sciu.us.txt
# /kaggle/input/Data/ETFs/eido.us.txt
# /kaggle/input/Data/ETFs/agz.us.txt
# /kaggle/input/Data/ETFs/upro.us.txt
# /kaggle/input/Data/ETFs/dbp.us.txt
# /kaggle/input/Data/ETFs/gasl.us.txt
# /kaggle/input/Data/ETFs/unl.us.txt
# /kaggle/input/Data/ETFs/dvya.us.txt
# /kaggle/input/Data/ETFs/sqqq.us.txt
# /kaggle/input/Data/ETFs/labd.us.txt
# /kaggle/input/Data/ETFs/vig.us.txt
# /kaggle/input/Data/ETFs/efo.us.txt
# /kaggle/input/Data/ETFs/near.us.txt
# /kaggle/input/Data/ETFs/dhs.us.txt
# /kaggle/input/Data/ETFs/crop.us.txt
# /kaggle/input/Data/ETFs/eqwl.us.txt
# /kaggle/input/Data/ETFs/agzd.us.txt
# /kaggle/input/Data/ETFs/adra.us.txt
# /kaggle/input/Data/ETFs/pgf.us.txt
# /kaggle/input/Data/ETFs/iat.us.txt
# /kaggle/input/Data/ETFs/ibce.us.txt
# /kaggle/input/Data/ETFs/fex.us.txt
# /kaggle/input/Data/ETFs/pwz.us.txt
# /kaggle/input/Data/ETFs/bsjm.us.txt
# /kaggle/input/Data/ETFs/fxd.us.txt
# /kaggle/input/Data/ETFs/smlf.us.txt
# /kaggle/input/Data/ETFs/ftsm.us.txt
# /kaggle/input/Data/ETFs/qaba.us.txt
# /kaggle/input/Data/ETFs/dto.us.txt
# /kaggle/input/Data/ETFs/alfa.us.txt
# /kaggle/input/Data/ETFs/qwld.us.txt
# /kaggle/input/Data/ETFs/qqqe.us.txt
# /kaggle/input/Data/ETFs/schh.us.txt
# /kaggle/input/Data/ETFs/tyd.us.txt
# /kaggle/input/Data/ETFs/xmpt.us.txt
# /kaggle/input/Data/ETFs/upv.us.txt
# /kaggle/input/Data/ETFs/fjp.us.txt
# /kaggle/input/Data/ETFs/erx.us.txt
# /kaggle/input/Data/ETFs/ust.us.txt
# /kaggle/input/Data/ETFs/ubt.us.txt
# /kaggle/input/Data/ETFs/scj.us.txt
# /kaggle/input/Data/ETFs/vxz.us.txt
# /kaggle/input/Data/ETFs/fems.us.txt
# /kaggle/input/Data/ETFs/ibmh.us.txt
# /kaggle/input/Data/ETFs/iqde.us.txt
# /kaggle/input/Data/ETFs/ewl.us.txt
# /kaggle/input/Data/ETFs/tipz.us.txt
# /kaggle/input/Data/ETFs/xlu.us.txt
# /kaggle/input/Data/ETFs/ijk.us.txt
# /kaggle/input/Data/ETFs/nyf.us.txt
# /kaggle/input/Data/ETFs/minc.us.txt
# /kaggle/input/Data/ETFs/sgg.us.txt
# /kaggle/input/Data/ETFs/epv.us.txt
# /kaggle/input/Data/ETFs/jjn.us.txt
# /kaggle/input/Data/ETFs/dsi.us.txt
# /kaggle/input/Data/ETFs/pgm.us.txt
# /kaggle/input/Data/ETFs/ibdk.us.txt
# /kaggle/input/Data/ETFs/acwf.us.txt
# /kaggle/input/Data/ETFs/rwj.us.txt
# /kaggle/input/Data/ETFs/actx.us.txt
# /kaggle/input/Data/ETFs/fiw.us.txt
# /kaggle/input/Data/ETFs/eqwm.us.txt
# /kaggle/input/Data/ETFs/dvy.us.txt
# /kaggle/input/Data/ETFs/fieu.us.txt
# /kaggle/input/Data/ETFs/schm.us.txt
# /kaggle/input/Data/ETFs/srln.us.txt
# /kaggle/input/Data/ETFs/ipac.us.txt
# /kaggle/input/Data/ETFs/dbez.us.txt
# /kaggle/input/Data/ETFs/mdiv.us.txt
# /kaggle/input/Data/ETFs/jpge.us.txt
# /kaggle/input/Data/ETFs/ign.us.txt
# /kaggle/input/Data/ETFs/dirt.us.txt
# /kaggle/input/Data/ETFs/schf.us.txt
# /kaggle/input/Data/ETFs/mna.us.txt
# /kaggle/input/Data/ETFs/srs.us.txt
# /kaggle/input/Data/ETFs/ieus.us.txt
# /kaggle/input/Data/ETFs/vlue.us.txt
# /kaggle/input/Data/ETFs/gunr.us.txt
# /kaggle/input/Data/ETFs/hspx.us.txt
# /kaggle/input/Data/ETFs/lvl.us.txt
# /kaggle/input/Data/ETFs/emlc.us.txt
# /kaggle/input/Data/ETFs/xmlv.us.txt
# /kaggle/input/Data/ETFs/rwx.us.txt
# /kaggle/input/Data/ETFs/spxh.us.txt
# /kaggle/input/Data/ETFs/dvhl.us.txt
# /kaggle/input/Data/ETFs/trsk.us.txt
# /kaggle/input/Data/ETFs/fhlc.us.txt
# /kaggle/input/Data/ETFs/inkm.us.txt
# /kaggle/input/Data/ETFs/pplt.us.txt
# /kaggle/input/Data/ETFs/vtwg.us.txt
# /kaggle/input/Data/ETFs/pff.us.txt
# /kaggle/input/Data/ETFs/cwb.us.txt
# /kaggle/input/Data/ETFs/iym.us.txt
# /kaggle/input/Data/ETFs/ddp.us.txt
# /kaggle/input/Data/ETFs/mrgr.us.txt
# /kaggle/input/Data/ETFs/dbgr.us.txt
# /kaggle/input/Data/ETFs/mlpa.us.txt
# /kaggle/input/Data/ETFs/voe.us.txt
# /kaggle/input/Data/ETFs/dia.us.txt
# /kaggle/input/Data/ETFs/kie.us.txt
# /kaggle/input/Data/ETFs/oneq.us.txt
# /kaggle/input/Data/ETFs/blv.us.txt
# /kaggle/input/Data/ETFs/icln.us.txt
# /kaggle/input/Data/ETFs/emb.us.txt
# /kaggle/input/Data/ETFs/qgbr.us.txt
# /kaggle/input/Data/ETFs/fndx.us.txt
# /kaggle/input/Data/ETFs/slyg.us.txt
# /kaggle/input/Data/ETFs/cred.us.txt
# /kaggle/input/Data/ETFs/ewx.us.txt
# /kaggle/input/Data/ETFs/qdef.us.txt
# /kaggle/input/Data/ETFs/grn.us.txt
# /kaggle/input/Data/ETFs/axjl.us.txt
# /kaggle/input/Data/ETFs/gsg.us.txt
# /kaggle/input/Data/ETFs/fthi.us.txt
# /kaggle/input/Data/ETFs/vbr.us.txt
# /kaggle/input/Data/ETFs/femb.us.txt
# /kaggle/input/Data/ETFs/rtm.us.txt
# /kaggle/input/Data/ETFs/ewp.us.txt
# /kaggle/input/Data/ETFs/nib.us.txt
# /kaggle/input/Data/ETFs/mgv.us.txt
# /kaggle/input/Data/ETFs/fxeu.us.txt
# /kaggle/input/Data/ETFs/dbjp.us.txt
# /kaggle/input/Data/ETFs/pmr.us.txt
# /kaggle/input/Data/ETFs/imlp.us.txt
# /kaggle/input/Data/ETFs/soxx.us.txt
# /kaggle/input/Data/ETFs/vong.us.txt
# /kaggle/input/Data/ETFs/sjb.us.txt
# /kaggle/input/Data/ETFs/schx.us.txt
# /kaggle/input/Data/ETFs/djci.us.txt
# /kaggle/input/Data/ETFs/fbt.us.txt
# /kaggle/input/Data/ETFs/bnd.us.txt
# /kaggle/input/Data/ETFs/fmat.us.txt
# /kaggle/input/Data/ETFs/fxz.us.txt
# /kaggle/input/Data/ETFs/fcan.us.txt
# /kaggle/input/Data/ETFs/iyj.us.txt
# /kaggle/input/Data/ETFs/uwm.us.txt
# /kaggle/input/Data/ETFs/labu.us.txt
# /kaggle/input/Data/ETFs/eufx.us.txt
# /kaggle/input/Data/ETFs/lowc.us.txt
# /kaggle/input/Data/ETFs/bick.us.txt
# /kaggle/input/Data/ETFs/crbn.us.txt
# /kaggle/input/Data/ETFs/gdxx.us.txt
# /kaggle/input/Data/ETFs/xhb.us.txt
# /kaggle/input/Data/ETFs/pscd.us.txt
# /kaggle/input/Data/ETFs/dbef.us.txt
# /kaggle/input/Data/ETFs/sso.us.txt
# /kaggle/input/Data/ETFs/splx.us.txt
# /kaggle/input/Data/ETFs/hap.us.txt
# /kaggle/input/Data/ETFs/xar.us.txt
# /kaggle/input/Data/ETFs/vox.us.txt
# /kaggle/input/Data/ETFs/dbbr.us.txt
# /kaggle/input/Data/ETFs/iye.us.txt
# /kaggle/input/Data/ETFs/erus.us.txt
# /kaggle/input/Data/ETFs/bbh.us.txt
# /kaggle/input/Data/ETFs/ivog.us.txt
# /kaggle/input/Data/ETFs/drw.us.txt
# /kaggle/input/Data/ETFs/iyz.us.txt
# /kaggle/input/Data/ETFs/efa.us.txt
# /kaggle/input/Data/ETFs/fsd.us.txt
# /kaggle/input/Data/ETFs/dew.us.txt
# /kaggle/input/Data/ETFs/finu.us.txt
# /kaggle/input/Data/ETFs/vnq.us.txt
# /kaggle/input/Data/ETFs/iemg.us.txt
# /kaggle/input/Data/ETFs/dth.us.txt
# /kaggle/input/Data/ETFs/fcor.us.txt
# /kaggle/input/Data/ETFs/pghy.us.txt
# /kaggle/input/Data/ETFs/mlps.us.txt
# /kaggle/input/Data/ETFs/jkf.us.txt
# /kaggle/input/Data/ETFs/picb.us.txt
# /kaggle/input/Data/ETFs/tyns.us.txt
# /kaggle/input/Data/ETFs/rez.us.txt
# /kaggle/input/Data/ETFs/ibdn.us.txt
# /kaggle/input/Data/ETFs/retl.us.txt
# /kaggle/input/Data/ETFs/viix.us.txt
# /kaggle/input/Data/ETFs/ycs.us.txt
# /kaggle/input/Data/ETFs/rwl.us.txt
# /kaggle/input/Data/ETFs/ddg.us.txt
# /kaggle/input/Data/ETFs/tbx.us.txt
# /kaggle/input/Data/ETFs/vss.us.txt
# /kaggle/input/Data/ETFs/iwl.us.txt
# /kaggle/input/Data/ETFs/pjp.us.txt
# /kaggle/input/Data/ETFs/indl.us.txt
# /kaggle/input/Data/ETFs/fxf.us.txt
# /kaggle/input/Data/ETFs/hyls.us.txt
# /kaggle/input/Data/ETFs/amj.us.txt
# /kaggle/input/Data/ETFs/fku.us.txt
# /kaggle/input/Data/ETFs/dgre.us.txt
# /kaggle/input/Data/ETFs/jnk.us.txt
# /kaggle/input/Data/ETFs/ici.us.txt
# /kaggle/input/Data/ETFs/qinc.us.txt
# /kaggle/input/Data/ETFs/ewc.us.txt
# /kaggle/input/Data/ETFs/corn.us.txt
# /kaggle/input/Data/ETFs/ffr.us.txt
# /kaggle/input/Data/ETFs/uci.us.txt
# /kaggle/input/Data/ETFs/ldur.us.txt
# /kaggle/input/Data/ETFs/tlh.us.txt
# /kaggle/input/Data/ETFs/ashs.us.txt
# /kaggle/input/Data/ETFs/grek.us.txt
# /kaggle/input/Data/ETFs/fxo.us.txt
# /kaggle/input/Data/ETFs/ebnd.us.txt
# /kaggle/input/Data/ETFs/axjv.us.txt
# /kaggle/input/Data/ETFs/ibdd.us.txt
# /kaggle/input/Data/ETFs/bom.us.txt
# /kaggle/input/Data/ETFs/vpu.us.txt
# /kaggle/input/Data/ETFs/ivv.us.txt
# /kaggle/input/Data/ETFs/ecns.us.txt
# /kaggle/input/Data/ETFs/sgdj.us.txt
# /kaggle/input/Data/ETFs/agq.us.txt
# /kaggle/input/Data/ETFs/sphb.us.txt
# /kaggle/input/Data/ETFs/know.us.txt
# /kaggle/input/Data/ETFs/dim.us.txt
# /kaggle/input/Data/ETFs/chiq.us.txt
# /kaggle/input/Data/ETFs/finz.us.txt
# /kaggle/input/Data/ETFs/fln.us.txt
# /kaggle/input/Data/ETFs/ezj.us.txt
# /kaggle/input/Data/ETFs/mlpi.us.txt
# /kaggle/input/Data/ETFs/gdxj.us.txt
# /kaggle/input/Data/ETFs/cnda.us.txt
# /kaggle/input/Data/ETFs/szk.us.txt
# /kaggle/input/Data/ETFs/fpa.us.txt
# /kaggle/input/Data/ETFs/itb.us.txt
# /kaggle/input/Data/ETFs/pxmv.us.txt
# /kaggle/input/Data/ETFs/ycl.us.txt
# /kaggle/input/Data/ETFs/qus.us.txt
# /kaggle/input/Data/ETFs/udn.us.txt
# /kaggle/input/Data/ETFs/ewq.us.txt
# /kaggle/input/Data/ETFs/exi.us.txt
# /kaggle/input/Data/ETFs/rhs.us.txt
# /kaggle/input/Data/ETFs/igih.us.txt
# /kaggle/input/Data/ETFs/muni.us.txt
# /kaggle/input/Data/ETFs/gii.us.txt
# /kaggle/input/Data/ETFs/nash.us.txt
# /kaggle/input/Data/ETFs/jja.us.txt
# /kaggle/input/Data/ETFs/russ.us.txt
# /kaggle/input/Data/ETFs/feuz.us.txt
# /kaggle/input/Data/ETFs/scto.us.txt
# /kaggle/input/Data/ETFs/eet.us.txt
# /kaggle/input/Data/ETFs/spxu.us.txt
# /kaggle/input/Data/ETFs/dag.us.txt
# /kaggle/input/Data/ETFs/jjp.us.txt
# /kaggle/input/Data/ETFs/efu.us.txt
# /kaggle/input/Data/ETFs/fif.us.txt
# /kaggle/input/Data/ETFs/vnm.us.txt
# /kaggle/input/Data/ETFs/ravi.us.txt
# /kaggle/input/Data/ETFs/drv.us.txt
# /kaggle/input/Data/ETFs/eis.us.txt
# /kaggle/input/Data/ETFs/dgaz.us.txt
# /kaggle/input/Data/ETFs/ewi.us.txt
# /kaggle/input/Data/ETFs/jo.us.txt
# /kaggle/input/Data/ETFs/vqt.us.txt
# /kaggle/input/Data/ETFs/ivov.us.txt
# /kaggle/input/Data/ETFs/qqqc.us.txt
# /kaggle/input/Data/ETFs/cqqq.us.txt
# /kaggle/input/Data/ETFs/pscu.us.txt
# /kaggle/input/Data/ETFs/pey.us.txt
# /kaggle/input/Data/ETFs/ero.us.txt
# /kaggle/input/Data/ETFs/tur.us.txt
# /kaggle/input/Data/ETFs/vgk.us.txt
# /kaggle/input/Data/ETFs/vot.us.txt
# /kaggle/input/Data/ETFs/soil.us.txt
# /kaggle/input/Data/ETFs/xhs.us.txt
# /kaggle/input/Data/ETFs/voog.us.txt
# /kaggle/input/Data/ETFs/rxl.us.txt
# /kaggle/input/Data/ETFs/adru.us.txt
# /kaggle/input/Data/ETFs/iefa.us.txt
# /kaggle/input/Data/ETFs/fez.us.txt
# /kaggle/input/Data/ETFs/mbb.us.txt
# /kaggle/input/Data/ETFs/xop.us.txt
# /kaggle/input/Data/ETFs/don.us.txt
# /kaggle/input/Data/ETFs/rsp.us.txt
# /kaggle/input/Data/ETFs/fltb.us.txt
# /kaggle/input/Data/ETFs/sbm.us.txt
# /kaggle/input/Data/ETFs/jjm.us.txt
# /kaggle/input/Data/ETFs/vgsh.us.txt
# /kaggle/input/Data/ETFs/enzl.us.txt
# /kaggle/input/Data/ETFs/dust.us.txt
# /kaggle/input/Data/ETFs/ijt.us.txt
# /kaggle/input/Data/ETFs/slx.us.txt
# /kaggle/input/Data/ETFs/gmf.us.txt
# /kaggle/input/Data/ETFs/slqd.us.txt
# /kaggle/input/Data/ETFs/nge.us.txt
# /kaggle/input/Data/ETFs/cza.us.txt
# /kaggle/input/Data/ETFs/xsd.us.txt
# /kaggle/input/Data/ETFs/slvp.us.txt
# /kaggle/input/Data/ETFs/svxy.us.txt
# /kaggle/input/Data/ETFs/pxh.us.txt
# /kaggle/input/Data/ETFs/dgrs.us.txt
# /kaggle/input/Data/ETFs/fri.us.txt
# /kaggle/input/Data/ETFs/mchi.us.txt
# /kaggle/input/Data/ETFs/syv.us.txt
# /kaggle/input/Data/ETFs/mfd.us.txt
# /kaggle/input/Data/ETFs/ewh.us.txt
# /kaggle/input/Data/ETFs/dxjf.us.txt
# /kaggle/input/Data/ETFs/vglt.us.txt
# /kaggle/input/Data/ETFs/huse.us.txt
# /kaggle/input/Data/ETFs/vcr.us.txt
# /kaggle/input/Data/ETFs/bsjj.us.txt
# /kaggle/input/Data/ETFs/vthr.us.txt
# /kaggle/input/Data/ETFs/bwx.us.txt
# /kaggle/input/Data/ETFs/indy.us.txt
# /kaggle/input/Data/ETFs/rja.us.txt
# /kaggle/input/Data/ETFs/bond.us.txt
# /kaggle/input/Data/ETFs/jju.us.txt
# /kaggle/input/Data/ETFs/scc.us.txt
# /kaggle/input/Data/ETFs/aaxj.us.txt
# /kaggle/input/Data/ETFs/vioo.us.txt
# /kaggle/input/Data/ETFs/tlte.us.txt
# /kaggle/input/Data/ETFs/fxl.us.txt
# /kaggle/input/Data/ETFs/ihy.us.txt
# /kaggle/input/Data/ETFs/idlv.us.txt
# /kaggle/input/Data/ETFs/size.us.txt
# /kaggle/input/Data/ETFs/rpv.us.txt
# /kaggle/input/Data/ETFs/corp.us.txt
# /kaggle/input/Data/ETFs/fnda.us.txt
# /kaggle/input/Data/ETFs/fab.us.txt
# /kaggle/input/Data/ETFs/spyg.us.txt
# /kaggle/input/Data/ETFs/iusb.us.txt
# /kaggle/input/Data/ETFs/dbko.us.txt
# /kaggle/input/Data/ETFs/bsji.us.txt
# /kaggle/input/Data/ETFs/iqlt.us.txt
# /kaggle/input/Data/ETFs/emif.us.txt
# /kaggle/input/Data/ETFs/uco.us.txt
# /kaggle/input/Data/ETFs/ftc.us.txt
# /kaggle/input/Data/ETFs/hyg.us.txt
# /kaggle/input/Data/ETFs/cane.us.txt
# /kaggle/input/Data/ETFs/efad.us.txt
# /kaggle/input/Data/ETFs/siz.us.txt
# /kaggle/input/Data/ETFs/pcy.us.txt
# /kaggle/input/Data/ETFs/pez.us.txt
# /kaggle/input/Data/ETFs/shv.us.txt
# /kaggle/input/Data/ETFs/qld.us.txt
# /kaggle/input/Data/ETFs/bdcl.us.txt
# /kaggle/input/Data/ETFs/vxf.us.txt
# /kaggle/input/Data/ETFs/spff.us.txt
# /kaggle/input/Data/ETFs/pbe.us.txt
# /kaggle/input/Data/ETFs/spy.us.txt
# /kaggle/input/Data/ETFs/sub.us.txt
# /kaggle/input/Data/ETFs/rals.us.txt
# /kaggle/input/Data/ETFs/bizd.us.txt
# /kaggle/input/Data/ETFs/qqq.us.txt
# /kaggle/input/Data/ETFs/ext.us.txt
# /kaggle/input/Data/ETFs/ihf.us.txt
# /kaggle/input/Data/ETFs/midu.us.txt
# /kaggle/input/Data/ETFs/acwx.us.txt
# /kaggle/input/Data/ETFs/koru.us.txt
# /kaggle/input/Data/ETFs/flrt.us.txt
# /kaggle/input/Data/ETFs/aadr.us.txt
# /kaggle/input/Data/ETFs/iwf.us.txt
# /kaggle/input/Data/ETFs/pscc.us.txt
# /kaggle/input/Data/ETFs/sphd.us.txt
# /kaggle/input/Data/ETFs/fxy.us.txt
# /kaggle/input/Data/ETFs/edc.us.txt
# /kaggle/input/Data/ETFs/bscn.us.txt
# /kaggle/input/Data/ETFs/tok.us.txt
# /kaggle/input/Data/ETFs/istb.us.txt
# /kaggle/input/Data/ETFs/scif.us.txt
# /kaggle/input/Data/ETFs/ezy.us.txt
# /kaggle/input/Data/ETFs/emlp.us.txt
# /kaggle/input/Data/ETFs/mgk.us.txt
# /kaggle/input/Data/ETFs/dba.us.txt
# /kaggle/input/Data/ETFs/chii.us.txt
# /kaggle/input/Data/ETFs/fko.us.txt
# /kaggle/input/Data/ETFs/ftec.us.txt
# /kaggle/input/Data/ETFs/flrn.us.txt
# /kaggle/input/Data/ETFs/usl.us.txt
# /kaggle/input/Data/ETFs/mzz.us.txt
# /kaggle/input/Data/ETFs/pxf.us.txt
# /kaggle/input/Data/ETFs/eufn.us.txt
# /kaggle/input/Data/ETFs/pwb.us.txt
# /kaggle/input/Data/ETFs/hyzd.us.txt
# /kaggle/input/Data/ETFs/pph.us.txt
# /kaggle/input/Data/ETFs/ibdm.us.txt
# /kaggle/input/Data/ETFs/hezu.us.txt
# /kaggle/input/Data/ETFs/ewv.us.txt
# /kaggle/input/Data/ETFs/def.us.txt
# /kaggle/input/Data/ETFs/cpi.us.txt
# /kaggle/input/Data/ETFs/sche.us.txt
# /kaggle/input/Data/ETFs/skyy.us.txt
# /kaggle/input/Data/ETFs/frn.us.txt
# /kaggle/input/Data/ETFs/smll.us.txt
# /kaggle/input/Data/ETFs/iscf.us.txt
# /kaggle/input/Data/ETFs/bbrc.us.txt
# /kaggle/input/Data/ETFs/psj.us.txt
# /kaggle/input/Data/ETFs/bis.us.txt
# /kaggle/input/Data/ETFs/iqdf.us.txt
# /kaggle/input/Data/ETFs/bwz.us.txt
# /kaggle/input/Data/ETFs/ftw.us.txt
# /kaggle/input/Data/ETFs/fni.us.txt
# /kaggle/input/Data/ETFs/tqqq.us.txt
# /kaggle/input/Data/ETFs/ezu.us.txt
# /kaggle/input/Data/ETFs/qai.us.txt
# /kaggle/input/Data/ETFs/dbaw.us.txt
# /kaggle/input/Data/ETFs/bscj.us.txt
# /kaggle/input/Data/ETFs/qdyn.us.txt
# /kaggle/input/Data/ETFs/tmf.us.txt
# /kaggle/input/Data/ETFs/xlk.us.txt
# /kaggle/input/Data/ETFs/fmb.us.txt
# /kaggle/input/Data/ETFs/ephe.us.txt
# /kaggle/input/Data/ETFs/mlpg.us.txt
# /kaggle/input/Data/ETFs/pbd.us.txt
# /kaggle/input/Data/ETFs/gdx.us.txt
# /kaggle/input/Data/ETFs/alts.us.txt
# /kaggle/input/Data/ETFs/dwx.us.txt
# /kaggle/input/Data/ETFs/vidi.us.txt
# /kaggle/input/Data/ETFs/pxlg.us.txt
# /kaggle/input/Data/ETFs/vxus.us.txt
# /kaggle/input/Data/ETFs/qjpn.us.txt
# /kaggle/input/Data/ETFs/llsp.us.txt
# /kaggle/input/Data/ETFs/xli.us.txt
# /kaggle/input/Data/ETFs/sds.us.txt
# /kaggle/input/Data/ETFs/ujb.us.txt
# /kaggle/input/Data/ETFs/ibcc.us.txt
# /kaggle/input/Data/ETFs/nlr.us.txt
# /kaggle/input/Data/ETFs/qat.us.txt
# /kaggle/input/Data/ETFs/sdow.us.txt
# /kaggle/input/Data/ETFs/gxc.us.txt
# /kaggle/input/Data/ETFs/dig.us.txt
# /kaggle/input/Data/ETFs/mmtm.us.txt
# /kaggle/input/Data/ETFs/pza.us.txt
# /kaggle/input/Data/ETFs/yao.us.txt
# /kaggle/input/Data/ETFs/efav.us.txt
# /kaggle/input/Data/ETFs/inco.us.txt
# /kaggle/input/Data/ETFs/igv.us.txt
# /kaggle/input/Data/ETFs/jpmv.us.txt
# /kaggle/input/Data/ETFs/pbp.us.txt
# /kaggle/input/Data/ETFs/ewo.us.txt
# /kaggle/input/Data/ETFs/cgw.us.txt
# /kaggle/input/Data/ETFs/hedj.us.txt
# /kaggle/input/Data/ETFs/dog.us.txt
# /kaggle/input/Data/ETFs/sco.us.txt
# /kaggle/input/Data/ETFs/fbnd.us.txt
# /kaggle/input/Data/ETFs/rwo.us.txt
# /kaggle/input/Data/ETFs/dfe.us.txt
# /kaggle/input/Data/ETFs/vdc.us.txt
# /kaggle/input/Data/ETFs/viiz.us.txt
# /kaggle/input/Data/ETFs/pwc.us.txt
# /kaggle/input/Data/ETFs/xph.us.txt
# /kaggle/input/Data/ETFs/choc.us.txt
# /kaggle/input/Data/ETFs/efv.us.txt
# /kaggle/input/Data/ETFs/pick.us.txt
# /kaggle/input/Data/ETFs/fct.us.txt
# /kaggle/input/Data/ETFs/flag.us.txt
# /kaggle/input/Data/ETFs/schv.us.txt
# /kaggle/input/Data/ETFs/qqxt.us.txt
# /kaggle/input/Data/ETFs/olem.us.txt
# /kaggle/input/Data/ETFs/fcom.us.txt
# /kaggle/input/Data/ETFs/wip.us.txt
# /kaggle/input/Data/ETFs/gnma.us.txt
# /kaggle/input/Data/ETFs/ewa.us.txt
# /kaggle/input/Data/ETFs/jki.us.txt
# /kaggle/input/Data/ETFs/fem.us.txt
# /kaggle/input/Data/ETFs/hys.us.txt
# /kaggle/input/Data/ETFs/fltr.us.txt
# /kaggle/input/Data/ETFs/eusa.us.txt
# /kaggle/input/Data/ETFs/robo.us.txt
# /kaggle/input/Data/ETFs/rew.us.txt
# /kaggle/input/Data/ETFs/yyy.us.txt
# /kaggle/input/Data/ETFs/hygh.us.txt
# /kaggle/input/Data/ETFs/iyw.us.txt
# /kaggle/input/Data/ETFs/iusg.us.txt
# /kaggle/input/Data/ETFs/oil.us.txt
# /kaggle/input/Data/ETFs/bsch.us.txt
# /kaggle/input/Data/ETFs/fpe.us.txt
# /kaggle/input/Data/ETFs/vea.us.txt
# /kaggle/input/Data/ETFs/xrt.us.txt
# /kaggle/input/Data/ETFs/tilt.us.txt
# /kaggle/input/Data/ETFs/ziv.us.txt
# /kaggle/input/Data/ETFs/fad.us.txt
# /kaggle/input/Data/ETFs/iak.us.txt
# /kaggle/input/Data/ETFs/schg.us.txt
# /kaggle/input/Data/ETFs/eden.us.txt
# /kaggle/input/Data/ETFs/smn.us.txt
# /kaggle/input/Data/ETFs/uxi.us.txt
# /kaggle/input/Data/ETFs/vym.us.txt
# /kaggle/input/Data/ETFs/vegi.us.txt
# /kaggle/input/Data/ETFs/skor.us.txt
# /kaggle/input/Data/ETFs/cn.us.txt
# /kaggle/input/Data/ETFs/fhk.us.txt
# /kaggle/input/Data/ETFs/fxa.us.txt
# /kaggle/input/Data/ETFs/mdyv.us.txt
# /kaggle/input/Data/ETFs/pscf.us.txt
# /kaggle/input/Data/ETFs/iyf.us.txt
# /kaggle/input/Data/ETFs/bsv.us.txt
# /kaggle/input/Data/ETFs/mvv.us.txt
# /kaggle/input/Data/ETFs/kba.us.txt
# /kaggle/input/Data/ETFs/psp.us.txt
# /kaggle/input/Data/ETFs/tlt.us.txt
# /kaggle/input/Data/ETFs/pxr.us.txt
# /kaggle/input/Data/ETFs/scha.us.txt
# /kaggle/input/Data/ETFs/dpk.us.txt
# /kaggle/input/Data/ETFs/gqre.us.txt
# /kaggle/input/Data/ETFs/emcg.us.txt
# /kaggle/input/Data/ETFs/sbio.us.txt
# /kaggle/input/Data/ETFs/carz.us.txt
# /kaggle/input/Data/ETFs/llsc.us.txt
# /kaggle/input/Data/ETFs/mtum.us.txt
# /kaggle/input/Data/ETFs/vaw.us.txt
# /kaggle/input/Data/ETFs/pzi.us.txt
# /kaggle/input/Data/ETFs/schr.us.txt
# /kaggle/input/Data/ETFs/pdbc.us.txt
# /kaggle/input/Data/ETFs/ryt.us.txt
# /kaggle/input/Data/ETFs/norw.us.txt
# /kaggle/input/Data/ETFs/jhdg.us.txt
# /kaggle/input/Data/ETFs/tfi.us.txt
# /kaggle/input/Data/ETFs/veu.us.txt
# /kaggle/input/Data/ETFs/wdiv.us.txt
# /kaggle/input/Data/ETFs/fta.us.txt
# /kaggle/input/Data/ETFs/iwn.us.txt
# /kaggle/input/Data/ETFs/copx.us.txt
# /kaggle/input/Data/ETFs/dug.us.txt
# /kaggle/input/Data/ETFs/usfr.us.txt
# /kaggle/input/Data/ETFs/frel.us.txt
# /kaggle/input/Data/ETFs/bal.us.txt
# /kaggle/input/Data/ETFs/eqws.us.txt
# /kaggle/input/Data/ETFs/dzz.us.txt
# /kaggle/input/Data/ETFs/emfm.us.txt
# /kaggle/input/Data/ETFs/fbgx.us.txt
# /kaggle/input/Data/ETFs/dxps.us.txt
# /kaggle/input/Data/ETFs/rwm.us.txt
# /kaggle/input/Data/ETFs/xlv.us.txt
# /kaggle/input/Data/ETFs/cbnd.us.txt
# /kaggle/input/Data/ETFs/agg.us.txt
# /kaggle/input/Data/ETFs/mbg.us.txt
# /kaggle/input/Data/ETFs/cny.us.txt
# /kaggle/input/Data/ETFs/kold.us.txt
# /kaggle/input/Data/ETFs/xlf.us.txt
# /kaggle/input/Data/ETFs/dbap.us.txt
# /kaggle/input/Data/ETFs/dbv.us.txt
# /kaggle/input/Data/ETFs/tecl.us.txt
# /kaggle/input/Data/ETFs/ppa.us.txt
# /kaggle/input/Data/ETFs/pxq.us.txt
# /kaggle/input/Data/ETFs/fep.us.txt
# /kaggle/input/Data/ETFs/mxi.us.txt
# /kaggle/input/Data/ETFs/smh.us.txt
# /kaggle/input/Data/ETFs/amjl.us.txt
# /kaggle/input/Data/ETFs/ieur.us.txt
# /kaggle/input/Data/ETFs/eld.us.txt
# /kaggle/input/Data/ETFs/gldi.us.txt
# /kaggle/input/Data/ETFs/fxch.us.txt
# /kaggle/input/Data/ETFs/fca.us.txt
# /kaggle/input/Data/ETFs/ioil.us.txt
# /kaggle/input/Data/ETFs/euo.us.txt
# /kaggle/input/Data/ETFs/faz.us.txt
# /kaggle/input/Data/ETFs/ghii.us.txt
# /kaggle/input/Data/ETFs/tan.us.txt
# /kaggle/input/Data/ETFs/scho.us.txt
# /kaggle/input/Data/ETFs/ibdj.us.txt
# /kaggle/input/Data/ETFs/chep.us.txt
# /kaggle/input/Data/ETFs/iwc.us.txt
# /kaggle/input/Data/ETFs/rinf.us.txt
# /kaggle/input/Data/ETFs/dno.us.txt
# /kaggle/input/Data/ETFs/uso.us.txt
# /kaggle/input/Data/ETFs/eum.us.txt
# /kaggle/input/Data/ETFs/bsjl.us.txt
# /kaggle/input/Data/ETFs/edz.us.txt
# /kaggle/input/Data/ETFs/gxf.us.txt
# /kaggle/input/Data/ETFs/ifeu.us.txt
# /kaggle/input/Data/ETFs/dwm.us.txt
# /kaggle/input/Data/ETFs/gex.us.txt
# /kaggle/input/Data/ETFs/bdd.us.txt
# /kaggle/input/Data/ETFs/chau.us.txt
# /kaggle/input/Data/ETFs/psk.us.txt
# /kaggle/input/Data/ETFs/jjs.us.txt
# /kaggle/input/Data/ETFs/fxi.us.txt
# /kaggle/input/Data/ETFs/wmcr.us.txt
# /kaggle/input/Data/ETFs/fvd.us.txt
# /kaggle/input/Data/ETFs/cow.us.txt
# /kaggle/input/Data/ETFs/vde.us.txt
# /kaggle/input/Data/ETFs/emih.us.txt
# /kaggle/input/Data/ETFs/futy.us.txt
# /kaggle/input/Data/ETFs/gsp.us.txt
# /kaggle/input/Data/ETFs/morl.us.txt
# /kaggle/input/Data/ETFs/adre.us.txt
# /kaggle/input/Data/ETFs/fny.us.txt
# /kaggle/input/Data/ETFs/bab.us.txt
# /kaggle/input/Data/ETFs/vug.us.txt
# /kaggle/input/Data/ETFs/csj.us.txt
# /kaggle/input/Data/ETFs/ixc.us.txt
# /kaggle/input/Data/ETFs/pcef.us.txt
# /kaggle/input/Data/ETFs/hewj.us.txt
# /kaggle/input/Data/ETFs/ewg.us.txt
# /kaggle/input/Data/ETFs/ipkw.us.txt
# /kaggle/input/Data/ETFs/nfra.us.txt
# /kaggle/input/Data/ETFs/icf.us.txt
# /kaggle/input/Data/ETFs/vis.us.txt
# /kaggle/input/Data/ETFs/cut.us.txt
# /kaggle/input/Data/ETFs/ibcd.us.txt
# /kaggle/input/Data/ETFs/vixm.us.txt
# /kaggle/input/Data/ETFs/shm.us.txt
# /kaggle/input/Data/ETFs/uym.us.txt
# /kaggle/input/Data/ETFs/wrei.us.txt
# /kaggle/input/Data/ETFs/xtn.us.txt
# /kaggle/input/Data/ETFs/ews.us.txt
# /kaggle/input/Data/ETFs/fdis.us.txt
# /kaggle/input/Data/ETFs/nugt.us.txt
# /kaggle/input/Data/ETFs/pfm.us.txt
# /kaggle/input/Data/ETFs/rpg.us.txt
# /kaggle/input/Data/ETFs/hdg.us.txt
# /kaggle/input/Data/ETFs/ryj.us.txt
# /kaggle/input/Data/ETFs/byld.us.txt
# /kaggle/input/Data/ETFs/brf.us.txt
# /kaggle/input/Data/ETFs/pfig.us.txt
# /kaggle/input/Data/ETFs/dzk.us.txt
# /kaggle/input/Data/ETFs/xme.us.txt
# /kaggle/input/Data/ETFs/grwn.us.txt
# /kaggle/input/Data/ETFs/myy.us.txt
# /kaggle/input/Data/ETFs/ixj.us.txt
# /kaggle/input/Data/ETFs/xes.us.txt
# /kaggle/input/Data/ETFs/snln.us.txt
# /kaggle/input/Data/ETFs/intf.us.txt
# /kaggle/input/Data/ETFs/smez.us.txt
# /kaggle/input/Data/ETFs/jkj.us.txt
# /kaggle/input/Data/ETFs/idx.us.txt
# /kaggle/input/Data/ETFs/vtip.us.txt
# /kaggle/input/Data/ETFs/iei.us.txt
# /kaggle/input/Data/ETFs/dvyl.us.txt
# /kaggle/input/Data/ETFs/ugaz.us.txt
# /kaggle/input/Data/ETFs/gltr.us.txt
# /kaggle/input/Data/ETFs/jjt.us.txt
# /kaggle/input/Data/ETFs/eemv.us.txt
# /kaggle/input/Data/ETFs/uvxy.us.txt
# /kaggle/input/Data/ETFs/sh.us.txt
# /kaggle/input/Data/ETFs/pak.us.txt
# /kaggle/input/Data/ETFs/sdp.us.txt
# /kaggle/input/Data/ETFs/hyd.us.txt
# /kaggle/input/Data/ETFs/pxe.us.txt
# /kaggle/input/Data/ETFs/croc.us.txt
# /kaggle/input/Data/ETFs/gal.us.txt
# /kaggle/input/Data/ETFs/moat.us.txt
# /kaggle/input/Data/ETFs/xly.us.txt
# /kaggle/input/Data/ETFs/gdxs.us.txt
# /kaggle/input/Data/ETFs/rth.us.txt
# /kaggle/input/Data/ETFs/tybs.us.txt
# /kaggle/input/Data/ETFs/iez.us.txt
# /kaggle/input/Data/ETFs/sly.us.txt
# /kaggle/input/Data/ETFs/rfv.us.txt
# /kaggle/input/Data/ETFs/fwdd.us.txt
# /kaggle/input/Data/ETFs/pbs.us.txt
# /kaggle/input/Data/ETFs/syg.us.txt
# /kaggle/input/Data/ETFs/cjnk.us.txt
# /kaggle/input/Data/ETFs/iwo.us.txt
# /kaggle/input/Data/ETFs/vrp.us.txt
# /kaggle/input/Data/ETFs/jkg.us.txt
# /kaggle/input/Data/ETFs/ive.us.txt
# /kaggle/input/Data/ETFs/ipo.us.txt
# /kaggle/input/Data/ETFs/schz.us.txt
# /kaggle/input/Data/ETFs/spyv.us.txt
# /kaggle/input/Data/ETFs/ibdl.us.txt
# /kaggle/input/Data/ETFs/fdm.us.txt
# /kaggle/input/Data/ETFs/drip.us.txt
# /kaggle/input/Data/ETFs/fdt.us.txt
# /kaggle/input/Data/ETFs/usd.us.txt
# /kaggle/input/Data/ETFs/dxjs.us.txt
# /kaggle/input/Data/ETFs/ryh.us.txt
# /kaggle/input/Data/ETFs/sdem.us.txt
# /kaggle/input/Data/ETFs/sij.us.txt
# /kaggle/input/Data/ETFs/vixy.us.txt
# /kaggle/input/Data/ETFs/bno.us.txt
# /kaggle/input/Data/ETFs/tdiv.us.txt
# /kaggle/input/Data/ETFs/hefa.us.txt
# /kaggle/input/Data/ETFs/ifgl.us.txt
# /kaggle/input/Data/ETFs/fbz.us.txt
# /kaggle/input/Data/ETFs/gush.us.txt
# /kaggle/input/Data/ETFs/rem.us.txt
# /kaggle/input/Data/ETFs/bdcs.us.txt
# /kaggle/input/Data/ETFs/fam.us.txt
# /kaggle/input/Data/ETFs/rigs.us.txt
# /kaggle/input/Data/ETFs/saa.us.txt
# /kaggle/input/Data/ETFs/dtd.us.txt
# /kaggle/input/Data/ETFs/ewzs.us.txt
# /kaggle/input/Data/ETFs/ibdq.us.txt
# /kaggle/input/Data/ETFs/soxl.us.txt
# /kaggle/input/Data/ETFs/dbuk.us.txt
# /kaggle/input/Data/ETFs/xle.us.txt
# /kaggle/input/Data/ETFs/ura.us.txt
# /kaggle/input/Data/ETFs/jkk.us.txt
# /kaggle/input/Data/ETFs/fan.us.txt
# /kaggle/input/Data/ETFs/chie.us.txt
# /kaggle/input/Data/ETFs/vcsh.us.txt
# /kaggle/input/Data/ETFs/scix.us.txt
# /kaggle/input/Data/ETFs/xbi.us.txt
# /kaggle/input/Data/ETFs/ite.us.txt
# /kaggle/input/Data/ETFs/ixg.us.txt
# /kaggle/input/Data/ETFs/kre.us.txt
# /kaggle/input/Data/ETFs/uga.us.txt
# /kaggle/input/Data/ETFs/tuz.us.txt
# /kaggle/input/Data/ETFs/smmu.us.txt
# /kaggle/input/Data/ETFs/sivr.us.txt
# /kaggle/input/Data/ETFs/gyen.us.txt
# /kaggle/input/Data/ETFs/itm.us.txt
# /kaggle/input/Data/ETFs/ftsd.us.txt
# /kaggle/input/Data/ETFs/acim.us.txt
# /kaggle/input/Data/ETFs/vone.us.txt
# /kaggle/input/Data/ETFs/flm.us.txt
# /kaggle/input/Data/ETFs/bsjh.us.txt
# /kaggle/input/Data/ETFs/vbk.us.txt
# /kaggle/input/Data/ETFs/eny.us.txt
# /kaggle/input/Data/ETFs/bndx.us.txt
# /kaggle/input/Data/ETFs/ixp.us.txt
# /kaggle/input/Data/ETFs/psi.us.txt
# /kaggle/input/Data/ETFs/eps.us.txt
# /kaggle/input/Data/ETFs/rwr.us.txt
# /kaggle/input/Data/ETFs/iwm.us.txt
# /kaggle/input/Data/ETFs/pxsv.us.txt
# /kaggle/input/Data/ETFs/ech.us.txt
# /kaggle/input/Data/ETFs/mint.us.txt
# /kaggle/input/Data/ETFs/ffa.us.txt
# /kaggle/input/Data/ETFs/ioo.us.txt
# /kaggle/input/Data/ETFs/hevy.us.txt
# /kaggle/input/Data/ETFs/dvye.us.txt
# /kaggle/input/Data/ETFs/dgrw.us.txt
# /kaggle/input/Data/ETFs/iwb.us.txt
# /kaggle/input/Data/ETFs/ydiv.us.txt
# /kaggle/input/Data/ETFs/tip.us.txt
# /kaggle/input/Data/ETFs/tltd.us.txt
# /kaggle/input/Data/ETFs/ewu.us.txt
# /kaggle/input/Data/ETFs/tdtt.us.txt
# /kaggle/input/Data/ETFs/inr.us.txt
# /kaggle/input/Data/ETFs/edv.us.txt
# /kaggle/input/Data/ETFs/faus.us.txt
# /kaggle/input/Data/ETFs/bsjk.us.txt
# /kaggle/input/Data/ETFs/vega.us.txt
# /kaggle/input/Data/ETFs/jjg.us.txt
# /kaggle/input/Data/ETFs/lemb.us.txt
# /kaggle/input/Data/ETFs/fnx.us.txt
# /kaggle/input/Data/ETFs/fxp.us.txt
# /kaggle/input/Data/ETFs/fv.us.txt
# /kaggle/input/Data/ETFs/kbwp.us.txt
# /kaggle/input/Data/ETFs/srty.us.txt
# /kaggle/input/Data/ETFs/bwv.us.txt
# /kaggle/input/Data/ETFs/eeh.us.txt
# /kaggle/input/Data/ETFs/emag.us.txt
# /kaggle/input/Data/ETFs/pgx.us.txt
# /kaggle/input/Data/ETFs/uyg.us.txt
# /kaggle/input/Data/ETFs/xsw.us.txt
# /kaggle/input/Data/ETFs/ibmi.us.txt
# /kaggle/input/Data/ETFs/cure.us.txt
# /kaggle/input/Data/ETFs/ees.us.txt
# /kaggle/input/Data/ETFs/gaa.us.txt
# /kaggle/input/Data/ETFs/paf.us.txt
# /kaggle/input/Data/ETFs/rgi.us.txt
# /kaggle/input/Data/ETFs/des.us.txt
# /kaggle/input/Data/ETFs/fxh.us.txt
# /kaggle/input/Data/ETFs/chim.us.txt
# /kaggle/input/Data/ETFs/mort.us.txt
# /kaggle/input/Data/ETFs/pzd.us.txt
# /kaggle/input/Data/ETFs/rsxj.us.txt
# /kaggle/input/Data/ETFs/zroz.us.txt
# /kaggle/input/Data/ETFs/jkh.us.txt
# /kaggle/input/Data/ETFs/ewj.us.txt
# /kaggle/input/Data/ETFs/aor.us.txt
# /kaggle/input/Data/ETFs/cew.us.txt
# /kaggle/input/Data/ETFs/vv.us.txt
# /kaggle/input/Data/ETFs/ijs.us.txt
# /kaggle/input/Data/ETFs/bscm.us.txt
# /kaggle/input/Data/ETFs/dln.us.txt
# /kaggle/input/Data/ETFs/rek.us.txt
# /kaggle/input/Data/ETFs/vpl.us.txt
# /kaggle/input/Data/ETFs/rwk.us.txt
# /kaggle/input/Data/ETFs/phdg.us.txt
# /kaggle/input/Data/ETFs/hynd.us.txt
# /kaggle/input/Data/ETFs/syld.us.txt
# /kaggle/input/Data/ETFs/olo.us.txt
# /kaggle/input/Data/ETFs/ixus.us.txt
# /kaggle/input/Data/ETFs/edog.us.txt
# /kaggle/input/Data/ETFs/usci.us.txt
# /kaggle/input/Data/ETFs/gll.us.txt
# /kaggle/input/Data/ETFs/ciu.us.txt
# /kaggle/input/Data/ETFs/sgol.us.txt
# /kaggle/input/Data/ETFs/kfyp.us.txt
# /kaggle/input/Data/ETFs/ounz.us.txt
# /kaggle/input/Data/ETFs/eelv.us.txt
# /kaggle/input/Data/ETFs/jje.us.txt
# /kaggle/input/Data/ETFs/eems.us.txt
# /kaggle/input/Data/ETFs/uslv.us.txt
# /kaggle/input/Data/ETFs/ihe.us.txt
# /kaggle/input/Data/ETFs/yinn.us.txt
# /kaggle/input/Data/ETFs/ilf.us.txt
# /kaggle/input/Data/ETFs/cmdt.us.txt
# /kaggle/input/Data/ETFs/tvix.us.txt
# /kaggle/input/Data/ETFs/shyd.us.txt
# /kaggle/input/Data/ETFs/afk.us.txt
# /kaggle/input/Data/ETFs/aok.us.txt
# /kaggle/input/Data/ETFs/pagg.us.txt
# /kaggle/input/Data/ETFs/feny.us.txt
# /kaggle/input/Data/ETFs/cwi.us.txt
# /kaggle/input/Data/ETFs/biv.us.txt
# /kaggle/input/Data/ETFs/fdd.us.txt
# /kaggle/input/Data/ETFs/ewm.us.txt
# /kaggle/input/Data/ETFs/wood.us.txt
# /kaggle/input/Data/ETFs/qtec.us.txt
# /kaggle/input/Data/ETFs/wps.us.txt
# /kaggle/input/Data/ETFs/heco.us.txt
# /kaggle/input/Data/ETFs/fieg.us.txt
# /kaggle/input/Data/ETFs/smdd.us.txt
# /kaggle/input/Data/ETFs/usdu.us.txt
# /kaggle/input/Data/ETFs/asea.us.txt
# /kaggle/input/Data/ETFs/sdd.us.txt
# /kaggle/input/Data/ETFs/vb.us.txt
# /kaggle/input/Data/ETFs/iyc.us.txt
# /kaggle/input/Data/ETFs/sret.us.txt
# /kaggle/input/Data/ETFs/ishg.us.txt
# /kaggle/input/Data/ETFs/pnqi.us.txt
# /kaggle/input/Data/ETFs/efz.us.txt
# /kaggle/input/Data/ETFs/jpnl.us.txt
# /kaggle/input/Data/ETFs/cape.us.txt
# /kaggle/input/Data/ETFs/zmlp.us.txt
# /kaggle/input/Data/ETFs/scz.us.txt
# /kaggle/input/Data/ETFs/epol.us.txt
# /kaggle/input/Data/ETFs/dbb.us.txt
# /kaggle/input/Data/ETFs/mlpc.us.txt
# /kaggle/input/Data/ETFs/fxsg.us.txt
# /kaggle/input/Data/ETFs/hilo.us.txt
# /kaggle/input/Data/ETFs/feo.us.txt
# /kaggle/input/Data/ETFs/fdn.us.txt
# /kaggle/input/Data/ETFs/fhy.us.txt
# /kaggle/input/Data/ETFs/idv.us.txt
# /kaggle/input/Data/ETFs/ijh.us.txt
# /kaggle/input/Data/ETFs/ung.us.txt
# /kaggle/input/Data/ETFs/eza.us.txt
# /kaggle/input/Data/ETFs/ubr.us.txt
# /kaggle/input/Data/ETFs/rcd.us.txt
# /kaggle/input/Data/ETFs/drn.us.txt
# /kaggle/input/Data/ETFs/ieo.us.txt
# /kaggle/input/Data/ETFs/urty.us.txt
# /kaggle/input/Data/ETFs/vuse.us.txt
# /kaggle/input/Data/ETFs/tflo.us.txt
# /kaggle/input/Data/ETFs/eeb.us.txt
# /kaggle/input/Data/ETFs/braq.us.txt
# /kaggle/input/Data/ETFs/ewy.us.txt
# /kaggle/input/Data/ETFs/fyx.us.txt
# /kaggle/input/Data/ETFs/iev.us.txt
# /kaggle/input/Data/ETFs/efg.us.txt
# /kaggle/input/Data/ETFs/acwi.us.txt
# /kaggle/input/Data/ETFs/ftcs.us.txt
# /kaggle/input/Data/ETFs/gval.us.txt
# /kaggle/input/Data/ETFs/airr.us.txt
# /kaggle/input/Data/ETFs/pio.us.txt
# /kaggle/input/Data/ETFs/smdv.us.txt
# /kaggle/input/Data/ETFs/fill.us.txt
# /kaggle/input/Data/ETFs/rjn.us.txt
# /kaggle/input/Data/ETFs/nobl.us.txt
# /kaggle/input/Data/ETFs/sdy.us.txt
# /kaggle/input/Data/ETFs/effe.us.txt
# /kaggle/input/Data/ETFs/mbsd.us.txt
# /kaggle/input/Data/ETFs/spuu.us.txt
# /kaggle/input/Data/ETFs/jxi.us.txt
# /kaggle/input/Data/ETFs/inda.us.txt
# /kaggle/input/Data/ETFs/gulf.us.txt
# /kaggle/input/Data/ETFs/prfz.us.txt
# /kaggle/input/Data/ETFs/ewd.us.txt
# /kaggle/input/Data/ETFs/slvo.us.txt
# /kaggle/input/Data/ETFs/rdiv.us.txt
# /kaggle/input/Data/ETFs/fncl.us.txt
# /kaggle/input/Data/ETFs/dxjh.us.txt
# /kaggle/input/Data/ETFs/vwo.us.txt
# /kaggle/input/Data/ETFs/fgb.us.txt
# /kaggle/input/Data/ETFs/argt.us.txt
# /kaggle/input/Data/ETFs/adrd.us.txt
# /kaggle/input/Data/ETFs/dbeu.us.txt
# /kaggle/input/Data/ETFs/ery.us.txt
# /kaggle/input/Data/ETFs/xvz.us.txt
# /kaggle/input/Data/ETFs/stip.us.txt
# /kaggle/input/Data/ETFs/ipe.us.txt
# /kaggle/input/Data/ETFs/fpx.us.txt
# /kaggle/input/Data/ETFs/ssg.us.txt
# /kaggle/input/Data/ETFs/rfg.us.txt
# /kaggle/input/Data/ETFs/heem.us.txt
# /kaggle/input/Data/ETFs/fnk.us.txt
# /kaggle/input/Data/ETFs/pall.us.txt
# /kaggle/input/Data/ETFs/viov.us.txt
# /kaggle/input/Data/ETFs/math.us.txt
# /kaggle/input/Data/ETFs/atmp.us.txt
# /kaggle/input/Data/ETFs/rzv.us.txt
# /kaggle/input/Data/ETFs/tbt.us.txt
# /kaggle/input/Data/ETFs/jdst.us.txt
# /kaggle/input/Data/ETFs/dfj.us.txt
# /kaggle/input/Data/ETFs/vti.us.txt
# /kaggle/input/Data/ETFs/tviz.us.txt
# /kaggle/input/Data/ETFs/fwdi.us.txt
# /kaggle/input/Data/ETFs/cmbs.us.txt
# /kaggle/input/Data/ETFs/eem.us.txt
# /kaggle/input/Data/ETFs/ezm.us.txt
# /kaggle/input/Data/ETFs/ubm.us.txt
# /kaggle/input/Data/ETFs/pst.us.txt
# /kaggle/input/Data/ETFs/csm.us.txt
# /kaggle/input/Data/ETFs/cefl.us.txt
# /kaggle/input/Data/ETFs/fyt.us.txt
# /kaggle/input/Data/ETFs/fmk.us.txt
# /kaggle/input/Data/ETFs/pgal.us.txt
# /kaggle/input/Data/ETFs/hyld.us.txt
# /kaggle/input/Data/ETFs/ibb.us.txt
# /kaggle/input/Data/ETFs/psq.us.txt
# /kaggle/input/Data/ETFs/tbf.us.txt
# /kaggle/input/Data/ETFs/chix.us.txt
# /kaggle/input/Data/ETFs/ptm.us.txt
# /kaggle/input/Data/ETFs/oih.us.txt
# /kaggle/input/Data/ETFs/ymlp.us.txt
# /kaggle/input/Data/ETFs/fxe.us.txt
# /kaggle/input/Data/ETFs/fndb.us.txt
# /kaggle/input/Data/ETFs/fsta.us.txt
# /kaggle/input/Data/ETFs/cafe.us.txt
# /kaggle/input/Data/ETFs/vonv.us.txt
# /kaggle/input/Data/ETFs/kxi.us.txt
# /kaggle/input/Data/ETFs/mgc.us.txt
# /kaggle/input/Data/ETFs/rye.us.txt
# /kaggle/input/Data/ETFs/iltb.us.txt
# /kaggle/input/Data/ETFs/iwy.us.txt
# /kaggle/input/Data/ETFs/pfxf.us.txt
# /kaggle/input/Data/ETFs/mlpy.us.txt
# /kaggle/input/Data/ETFs/dgld.us.txt
# /kaggle/input/Data/ETFs/feeu.us.txt
# /kaggle/input/Data/ETFs/amlp.us.txt
# /kaggle/input/Data/ETFs/ediv.us.txt
# /kaggle/input/Data/ETFs/fei.us.txt
# /kaggle/input/Data/ETFs/sphq.us.txt
# /kaggle/input/Data/ETFs/ubg.us.txt
# /kaggle/input/Data/ETFs/mln.us.txt
# /kaggle/input/Data/ETFs/tecs.us.txt
# /kaggle/input/Data/ETFs/xrlv.us.txt
# /kaggle/input/Data/ETFs/pgj.us.txt
# /kaggle/input/Data/ETFs/gri.us.txt
# /kaggle/input/Data/ETFs/inp.us.txt
# /kaggle/input/Data/ETFs/jke.us.txt
# /kaggle/input/Data/ETFs/ibdh.us.txt
# /kaggle/input/Data/ETFs/gxg.us.txt
# /kaggle/input/Data/ETFs/vcit.us.txt
# /kaggle/input/Data/ETFs/dnl.us.txt
# /kaggle/input/Data/ETFs/qcan.us.txt
# /kaggle/input/Data/ETFs/iwd.us.txt
# /kaggle/input/Data/ETFs/psau.us.txt
# /kaggle/input/Data/ETFs/dod.us.txt
# /kaggle/input/Data/ETFs/idhq.us.txt
# /kaggle/input/Data/ETFs/acwv.us.txt
# /kaggle/input/Data/ETFs/fndf.us.txt
# /kaggle/input/Data/ETFs/bscl.us.txt
# /kaggle/input/Data/ETFs/ijj.us.txt
# /kaggle/input/Data/ETFs/fwdb.us.txt
# /kaggle/input/Data/ETFs/fdiv.us.txt
# /kaggle/input/Data/ETFs/schd.us.txt
# /kaggle/input/Data/ETFs/upw.us.txt
# /kaggle/input/Data/ETFs/agnd.us.txt
# /kaggle/input/Data/Stocks/icui.us.txt
# /kaggle/input/Data/Stocks/finx.us.txt
# /kaggle/input/Data/Stocks/manh.us.txt
# /kaggle/input/Data/Stocks/hmtv.us.txt
# /kaggle/input/Data/Stocks/apo.us.txt
# /kaggle/input/Data/Stocks/eft.us.txt
# /kaggle/input/Data/Stocks/bgg.us.txt
# /kaggle/input/Data/Stocks/jazz.us.txt
# ...
# /kaggle/input/Data/Stocks/enb.us.txt
# /kaggle/input/Data/Stocks/nat.us.txt
# /kaggle/input/Data/Stocks/amh_d.us.txt
# /kaggle/input/Data/Stocks/sptm.us.txt
# /kaggle/input/Data/Stocks/xny.us.txt
# /kaggle/input/Data/Stocks/fbiz.us.txt
# /kaggle/input/Data/Stocks/resn.us.txt
# /kaggle/input/Data/Stocks/cbrl.us.txt
# /kaggle/input/Data/Stocks/lmnx.us.txt
# /kaggle/input/Data/Stocks/flio.us.txt
# /kaggle/input/Data/Stocks/qxtr.us.txt
# /kaggle/input/Data/Stocks/ugi.us.txt
# /kaggle/input/Data/Stocks/mtnb.us.txt
# /kaggle/input/Data/Stocks/cpac.us.txt
# /kaggle/input/Data/Stocks/ubsi.us.txt
# /kaggle/input/Data/Stocks/erj.us.txt
# /kaggle/input/Data/Stocks/esdi.us.txt
# /kaggle/input/Data/Stocks/ms_f.us.txt
# /kaggle/input/Data/Stocks/aeh.us.txt
# /kaggle/input/Data/Stocks/hos.us.txt
# /kaggle/input/Data/Stocks/mmac.us.txt
# /kaggle/input/Data/Stocks/btx.us.txt
# /kaggle/input/Data/Stocks/ver.us.txt
# /kaggle/input/Data/Stocks/dmlp.us.txt
# /kaggle/input/Data/Stocks/jrvr.us.txt
# /kaggle/input/Data/Stocks/nmfc.us.txt
# /kaggle/input/Data/Stocks/anet.us.txt
# /kaggle/input/Data/Stocks/msp.us.txt
# /kaggle/input/Data/Stocks/gkos.us.txt
# /kaggle/input/Data/Stocks/dea.us.txt
# /kaggle/input/Data/Stocks/star.us.txt
# /kaggle/input/Data/Stocks/keg.us.txt
# /kaggle/input/Data/Stocks/adp.us.txt
# /kaggle/input/Data/Stocks/spem.us.txt
# /kaggle/input/Data/Stocks/crws.us.txt
# /kaggle/input/Data/Stocks/r.us.txt
# /kaggle/input/Data/Stocks/wpx.us.txt
# /kaggle/input/Data/Stocks/divb.us.txt
# /kaggle/input/Data/Stocks/dnp.us.txt
# /kaggle/input/Data/Stocks/ergf.us.txt
# /kaggle/input/Data/Stocks/niq.us.txt
# /kaggle/input/Data/Stocks/wtid.us.txt
# /kaggle/input/Data/Stocks/hlne.us.txt
# /kaggle/input/Data/Stocks/band.us.txt
# /kaggle/input/Data/Stocks/asgn.us.txt
# /kaggle/input/Data/Stocks/ndaq.us.txt
# /kaggle/input/Data/Stocks/bk_c.us.txt
# /kaggle/input/Data/Stocks/del.us.txt
# /kaggle/input/Data/Stocks/kldx.us.txt
# /kaggle/input/Data/Stocks/icd.us.txt
# /kaggle/input/Data/Stocks/all.us.txt
# /kaggle/input/Data/Stocks/cvx.us.txt
# /kaggle/input/Data/Stocks/gpp.us.txt
# /kaggle/input/Data/Stocks/bkj.us.txt
# /kaggle/input/Data/Stocks/ltm.us.txt
# /kaggle/input/Data/Stocks/cvbf.us.txt
# /kaggle/input/Data/Stocks/gainn.us.txt
# /kaggle/input/Data/Stocks/feim.us.txt
# /kaggle/input/Data/Stocks/jtpy.us.txt
# /kaggle/input/Data/Stocks/tcbi.us.txt
# /kaggle/input/Data/Stocks/bsqr.us.txt
# /kaggle/input/Data/Stocks/ontl.us.txt
# /kaggle/input/Data/Stocks/mlco.us.txt
# /kaggle/input/Data/Stocks/asns.us.txt
# /kaggle/input/Data/Stocks/pty.us.txt
# /kaggle/input/Data/Stocks/bles.us.txt
# /kaggle/input/Data/Stocks/wtfcm.us.txt
# /kaggle/input/Data/Stocks/rhi.us.txt
# /kaggle/input/Data/Stocks/tif.us.txt
# /kaggle/input/Data/Stocks/sbbp.us.txt
# /kaggle/input/Data/Stocks/psb_v.us.txt
# /kaggle/input/Data/Stocks/ai_b.us.txt
# /kaggle/input/Data/Stocks/vsi.us.txt
# /kaggle/input/Data/Stocks/fce-a.us.txt
# /kaggle/input/Data/Stocks/lgcyp.us.txt
# /kaggle/input/Data/Stocks/mus.us.txt
# /kaggle/input/Data/Stocks/bl.us.txt
# /kaggle/input/Data/Stocks/duc.us.txt
# /kaggle/input/Data/Stocks/psa_c.us.txt
# /kaggle/input/Data/Stocks/afsi_e.us.txt
# /kaggle/input/Data/Stocks/wdc.us.txt
# /kaggle/input/Data/Stocks/esp.us.txt
# /kaggle/input/Data/Stocks/bce.us.txt
# /kaggle/input/Data/Stocks/ascma.us.txt
# /kaggle/input/Data/Stocks/ast.us.txt
# /kaggle/input/Data/Stocks/ccs.us.txt
# /kaggle/input/Data/Stocks/arna.us.txt
# /kaggle/input/Data/Stocks/idn.us.txt
# /kaggle/input/Data/Stocks/pag.us.txt
# /kaggle/input/Data/Stocks/ras.us.txt
# /kaggle/input/Data/Stocks/fsacu.us.txt
# /kaggle/input/Data/Stocks/ffin.us.txt
# /kaggle/input/Data/Stocks/jhmh.us.txt
# /kaggle/input/Data/Stocks/yum.us.txt
# /kaggle/input/Data/Stocks/pinc.us.txt
# /kaggle/input/Data/Stocks/cubs.us.txt
# /kaggle/input/Data/Stocks/senea.us.txt
# /kaggle/input/Data/Stocks/vygr.us.txt
# /kaggle/input/Data/Stocks/uti.us.txt
# /kaggle/input/Data/Stocks/ecr.us.txt
# /kaggle/input/Data/Stocks/tcon.us.txt
# /kaggle/input/Data/Stocks/spxn.us.txt
# /kaggle/input/Data/Stocks/qtm.us.txt
# /kaggle/input/Data/Stocks/szc.us.txt
# /kaggle/input/Data/Stocks/fisk.us.txt
# /kaggle/input/Data/Stocks/lway.us.txt
# /kaggle/input/Data/Stocks/ver_f.us.txt
# /kaggle/input/Data/Stocks/lrad.us.txt
# /kaggle/input/Data/Stocks/ftk.us.txt
# /kaggle/input/Data/Stocks/ibkcp.us.txt
# /kaggle/input/Data/Stocks/wtfc.us.txt
# /kaggle/input/Data/Stocks/pes.us.txt
# /kaggle/input/Data/Stocks/rely.us.txt
# /kaggle/input/Data/Stocks/mog-a.us.txt
# /kaggle/input/Data/Stocks/chrs.us.txt
# /kaggle/input/Data/Stocks/self.us.txt
# /kaggle/input/Data/Stocks/ctlt.us.txt
# /kaggle/input/Data/Stocks/slgn.us.txt
# /kaggle/input/Data/Stocks/wtr.us.txt
# /kaggle/input/Data/Stocks/chrw.us.txt
# /kaggle/input/Data/Stocks/glop.us.txt
# /kaggle/input/Data/Stocks/ttek.us.txt
# /kaggle/input/Data/Stocks/nem.us.txt
# /kaggle/input/Data/Stocks/mxc.us.txt
# /kaggle/input/Data/Stocks/bgb.us.txt
# /kaggle/input/Data/Stocks/prgx.us.txt
# /kaggle/input/Data/Stocks/rexx.us.txt
# /kaggle/input/Data/Stocks/cb.us.txt
# /kaggle/input/Data/Stocks/saft.us.txt
# /kaggle/input/Data/Stocks/cc.us.txt
# /kaggle/input/Data/Stocks/dnn.us.txt
# /kaggle/input/Data/Stocks/dhx.us.txt
# /kaggle/input/Data/Stocks/veri.us.txt
# /kaggle/input/Data/Stocks/plpm.us.txt
# /kaggle/input/Data/Stocks/botz.us.txt
# /kaggle/input/Data/Stocks/aytu.us.txt
# /kaggle/input/Data/Stocks/usau.us.txt
# /kaggle/input/Data/Stocks/ravn.us.txt
# /kaggle/input/Data/Stocks/wafd.us.txt
# /kaggle/input/Data/Stocks/iba.us.txt
# /kaggle/input/Data/Stocks/clyh.us.txt
# /kaggle/input/Data/Stocks/ntn.us.txt
# /kaggle/input/Data/Stocks/ttc.us.txt
# /kaggle/input/Data/Stocks/seneb.us.txt
# /kaggle/input/Data/Stocks/lgf-a.us.txt
# /kaggle/input/Data/Stocks/cjjd.us.txt
# /kaggle/input/Data/Stocks/dis.us.txt
# /kaggle/input/Data/Stocks/ttwo.us.txt
# /kaggle/input/Data/Stocks/lvhb.us.txt
# /kaggle/input/Data/Stocks/whr.us.txt
# /kaggle/input/Data/Stocks/blvdw.us.txt
# /kaggle/input/Data/Stocks/cxrx.us.txt
# /kaggle/input/Data/Stocks/sem.us.txt
# /kaggle/input/Data/Stocks/amx.us.txt
# /kaggle/input/Data/Stocks/jt.us.txt
# /kaggle/input/Data/Stocks/ffty.us.txt
# /kaggle/input/Data/Stocks/hgsh.us.txt
# /kaggle/input/Data/Stocks/usb_o.us.txt
# /kaggle/input/Data/Stocks/xshd.us.txt
# /kaggle/input/Data/Stocks/mvc.us.txt
# /kaggle/input/Data/Stocks/ois.us.txt
# /kaggle/input/Data/Stocks/ivlu.us.txt
# /kaggle/input/Data/Stocks/rsls.us.txt
# /kaggle/input/Data/Stocks/mdso.us.txt
# /kaggle/input/Data/Stocks/ssb.us.txt
# /kaggle/input/Data/Stocks/c_s.us.txt
# /kaggle/input/Data/Stocks/ftxn.us.txt
# /kaggle/input/Data/Stocks/bma.us.txt
# /kaggle/input/Data/Stocks/afsi_c.us.txt
# /kaggle/input/Data/Stocks/pmo.us.txt
# /kaggle/input/Data/Stocks/mofg.us.txt
# /kaggle/input/Data/Stocks/pdli.us.txt
# /kaggle/input/Data/Stocks/lpnt.us.txt
# /kaggle/input/Data/Stocks/rigl.us.txt
# /kaggle/input/Data/Stocks/smmd.us.txt
# /kaggle/input/Data/Stocks/main.us.txt
# /kaggle/input/Data/Stocks/sce_g.us.txt
# /kaggle/input/Data/Stocks/rpt.us.txt
# /kaggle/input/Data/Stocks/cenx.us.txt
# /kaggle/input/Data/Stocks/ghc.us.txt
# /kaggle/input/Data/Stocks/euxl.us.txt
# /kaggle/input/Data/Stocks/ifrx.us.txt
# /kaggle/input/Data/Stocks/vtr.us.txt
# /kaggle/input/Data/Stocks/sxe.us.txt
# /kaggle/input/Data/Stocks/albo.us.txt
# /kaggle/input/Data/Stocks/nvee.us.txt
# /kaggle/input/Data/Stocks/qmom.us.txt
# /kaggle/input/Data/Stocks/myi.us.txt
# /kaggle/input/Data/Stocks/agn_a.us.txt
# /kaggle/input/Data/Stocks/dmpi.us.txt
# /kaggle/input/Data/Stocks/isdr.us.txt
# /kaggle/input/Data/Stocks/selb.us.txt
# /kaggle/input/Data/Stocks/vhc.us.txt
# /kaggle/input/Data/Stocks/abx.us.txt
# /kaggle/input/Data/Stocks/mcy.us.txt
# /kaggle/input/Data/Stocks/bofil.us.txt
# /kaggle/input/Data/Stocks/fbhs.us.txt
# /kaggle/input/Data/Stocks/wti.us.txt
# /kaggle/input/Data/Stocks/ssnt.us.txt
# /kaggle/input/Data/Stocks/ares_a.us.txt
# /kaggle/input/Data/Stocks/bsf.us.txt
# /kaggle/input/Data/Stocks/ktec.us.txt
# /kaggle/input/Data/Stocks/rso.us.txt
# /kaggle/input/Data/Stocks/nm.us.txt
# /kaggle/input/Data/Stocks/cyh.us.txt
# /kaggle/input/Data/Stocks/vtnr.us.txt
# /kaggle/input/Data/Stocks/kep.us.txt
# /kaggle/input/Data/Stocks/tol.us.txt
# /kaggle/input/Data/Stocks/ftxd.us.txt
# /kaggle/input/Data/Stocks/bibl.us.txt
# /kaggle/input/Data/Stocks/tenx.us.txt
# /kaggle/input/Data/Stocks/nby.us.txt
# /kaggle/input/Data/Stocks/gshtw.us.txt
# /kaggle/input/Data/Stocks/cvrs.us.txt
# /kaggle/input/Data/Stocks/icch.us.txt
# /kaggle/input/Data/Stocks/aiw.us.txt
# /kaggle/input/Data/Stocks/tnc.us.txt
# /kaggle/input/Data/Stocks/tnk.us.txt
# /kaggle/input/Data/Stocks/isze.us.txt
# /kaggle/input/Data/Stocks/dfs_b-cl.us.txt
# /kaggle/input/Data/Stocks/tsi.us.txt
# /kaggle/input/Data/Stocks/ffbw.us.txt
# /kaggle/input/Data/Stocks/mab.us.txt
# /kaggle/input/Data/Stocks/mo.us.txt
# /kaggle/input/Data/Stocks/pwod.us.txt
# /kaggle/input/Data/Stocks/met_a.us.txt
# /kaggle/input/Data/Stocks/catb.us.txt
# /kaggle/input/Data/Stocks/cfco.us.txt
# /kaggle/input/Data/Stocks/goog.us.txt
# /kaggle/input/Data/Stocks/wba.us.txt
# /kaggle/input/Data/Stocks/asnd.us.txt
# /kaggle/input/Data/Stocks/chscp.us.txt
# /kaggle/input/Data/Stocks/gsbd.us.txt
# /kaggle/input/Data/Stocks/vco.us.txt
# /kaggle/input/Data/Stocks/avxs.us.txt
# /kaggle/input/Data/Stocks/krp.us.txt
# /kaggle/input/Data/Stocks/wbic.us.txt
# /kaggle/input/Data/Stocks/elon.us.txt
# /kaggle/input/Data/Stocks/bcacu.us.txt
# /kaggle/input/Data/Stocks/mcv.us.txt
# /kaggle/input/Data/Stocks/nid.us.txt
# /kaggle/input/Data/Stocks/bdx.us.txt
# /kaggle/input/Data/Stocks/edit.us.txt
# /kaggle/input/Data/Stocks/bctf.us.txt
# /kaggle/input/Data/Stocks/chtr.us.txt
# /kaggle/input/Data/Stocks/enic.us.txt
# /kaggle/input/Data/Stocks/dwld.us.txt
# /kaggle/input/Data/Stocks/bfk.us.txt
# /kaggle/input/Data/Stocks/gxp.us.txt
# /kaggle/input/Data/Stocks/odp.us.txt
# /kaggle/input/Data/Stocks/gmta.us.txt
# /kaggle/input/Data/Stocks/cifs.us.txt
# /kaggle/input/Data/Stocks/gs_c.us.txt
# /kaggle/input/Data/Stocks/tkr.us.txt
# /kaggle/input/Data/Stocks/roseu.us.txt
# /kaggle/input/Data/Stocks/npv.us.txt
# /kaggle/input/Data/Stocks/call.us.txt
# /kaggle/input/Data/Stocks/lng.us.txt
# /kaggle/input/Data/Stocks/esgw.us.txt
# /kaggle/input/Data/Stocks/fbp.us.txt
# /kaggle/input/Data/Stocks/aht.us.txt
# /kaggle/input/Data/Stocks/miii.us.txt
# /kaggle/input/Data/Stocks/kbwy.us.txt
# /kaggle/input/Data/Stocks/gdi.us.txt
# /kaggle/input/Data/Stocks/snh.us.txt
# /kaggle/input/Data/Stocks/itus.us.txt
# /kaggle/input/Data/Stocks/clf.us.txt
# /kaggle/input/Data/Stocks/bki.us.txt
# /kaggle/input/Data/Stocks/plt.us.txt
# /kaggle/input/Data/Stocks/dks.us.txt
# /kaggle/input/Data/Stocks/sq.us.txt
# /kaggle/input/Data/Stocks/psa_w.us.txt
# /kaggle/input/Data/Stocks/pkbk.us.txt
# /kaggle/input/Data/Stocks/pw_a.us.txt
# /kaggle/input/Data/Stocks/alle.us.txt
# /kaggle/input/Data/Stocks/lly.us.txt
# /kaggle/input/Data/Stocks/ubcp.us.txt
# /kaggle/input/Data/Stocks/rs.us.txt
# /kaggle/input/Data/Stocks/jbht.us.txt
# /kaggle/input/Data/Stocks/mscc.us.txt
# /kaggle/input/Data/Stocks/vkq.us.txt
# /kaggle/input/Data/Stocks/bax.us.txt
# /kaggle/input/Data/Stocks/asr.us.txt
# /kaggle/input/Data/Stocks/andau.us.txt
# /kaggle/input/Data/Stocks/sndr.us.txt
# /kaggle/input/Data/Stocks/enlc.us.txt
# /kaggle/input/Data/Stocks/omn.us.txt
# /kaggle/input/Data/Stocks/inov.us.txt
# /kaggle/input/Data/Stocks/elec.us.txt
# /kaggle/input/Data/Stocks/gms.us.txt
# /kaggle/input/Data/Stocks/myos.us.txt
# /kaggle/input/Data/Stocks/pmom.us.txt
# /kaggle/input/Data/Stocks/qlys.us.txt
# /kaggle/input/Data/Stocks/banf.us.txt
# /kaggle/input/Data/Stocks/aggp.us.txt
# /kaggle/input/Data/Stocks/mho.us.txt
# /kaggle/input/Data/Stocks/ihd.us.txt
# /kaggle/input/Data/Stocks/immy.us.txt
# /kaggle/input/Data/Stocks/frc.us.txt
# /kaggle/input/Data/Stocks/znga.us.txt
# /kaggle/input/Data/Stocks/arcw.us.txt
# /kaggle/input/Data/Stocks/ptnr.us.txt
# /kaggle/input/Data/Stocks/egy.us.txt
# /kaggle/input/Data/Stocks/tel.us.txt
# /kaggle/input/Data/Stocks/eurn.us.txt
# /kaggle/input/Data/Stocks/esrt.us.txt
# /kaggle/input/Data/Stocks/aray.us.txt
# /kaggle/input/Data/Stocks/mdvxw.us.txt
# /kaggle/input/Data/Stocks/gmz.us.txt
# /kaggle/input/Data/Stocks/odc.us.txt
# /kaggle/input/Data/Stocks/mfcb.us.txt
# /kaggle/input/Data/Stocks/cgnx.us.txt
# /kaggle/input/Data/Stocks/wppgy.us.txt
# /kaggle/input/Data/Stocks/ptsi.us.txt
# /kaggle/input/Data/Stocks/jbl.us.txt
# /kaggle/input/Data/Stocks/hele.us.txt
# /kaggle/input/Data/Stocks/mtge.us.txt
# /kaggle/input/Data/Stocks/bxp_b.us.txt
# /kaggle/input/Data/Stocks/evp.us.txt
# /kaggle/input/Data/Stocks/ht_e.us.txt
# /kaggle/input/Data/Stocks/tast.us.txt
# /kaggle/input/Data/Stocks/mays.us.txt
# /kaggle/input/Data/Stocks/ncb.us.txt
# /kaggle/input/Data/Stocks/snv_c.us.txt
# /kaggle/input/Data/Stocks/phiik.us.txt
# /kaggle/input/Data/Stocks/boxl.us.txt
# /kaggle/input/Data/Stocks/pm.us.txt
# /kaggle/input/Data/Stocks/cytx.us.txt
# /kaggle/input/Data/Stocks/ccbg.us.txt
# /kaggle/input/Data/Stocks/cgg.us.txt
# /kaggle/input/Data/Stocks/cmo.us.txt
# /kaggle/input/Data/Stocks/chco.us.txt
# /kaggle/input/Data/Stocks/bmi.us.txt
# /kaggle/input/Data/Stocks/nycb.us.txt
# /kaggle/input/Data/Stocks/cbk.us.txt
# /kaggle/input/Data/Stocks/amrhw.us.txt
# /kaggle/input/Data/Stocks/pstb.us.txt
# /kaggle/input/Data/Stocks/ahgp.us.txt
# /kaggle/input/Data/Stocks/iqdg.us.txt
# /kaggle/input/Data/Stocks/cptal.us.txt
# /kaggle/input/Data/Stocks/ctg.us.txt
# /kaggle/input/Data/Stocks/pcn.us.txt
# /kaggle/input/Data/Stocks/sito.us.txt
# /kaggle/input/Data/Stocks/jll.us.txt
# /kaggle/input/Data/Stocks/tgp_b.us.txt
# /kaggle/input/Data/Stocks/ulbi.us.txt
# /kaggle/input/Data/Stocks/tpc.us.txt
# /kaggle/input/Data/Stocks/sbrap.us.txt
# /kaggle/input/Data/Stocks/fnlc.us.txt
# /kaggle/input/Data/Stocks/pdlb.us.txt
# /kaggle/input/Data/Stocks/zg.us.txt
# /kaggle/input/Data/Stocks/cfr_a.us.txt
# /kaggle/input/Data/Stocks/isr.us.txt
# /kaggle/input/Data/Stocks/crak.us.txt
# /kaggle/input/Data/Stocks/bdc_b.us.txt
# /kaggle/input/Data/Stocks/fdlo.us.txt
# /kaggle/input/Data/Stocks/hacv.us.txt
# /kaggle/input/Data/Stocks/aobc.us.txt
# /kaggle/input/Data/Stocks/iova.us.txt
# /kaggle/input/Data/Stocks/awx.us.txt
# /kaggle/input/Data/Stocks/era.us.txt
# /kaggle/input/Data/Stocks/pzrx.us.txt
# /kaggle/input/Data/Stocks/cey.us.txt
# /kaggle/input/Data/Stocks/hrtg.us.txt
# /kaggle/input/Data/Stocks/wrlsu.us.txt
# /kaggle/input/Data/Stocks/plbc.us.txt
# /kaggle/input/Data/Stocks/mgm.us.txt
# /kaggle/input/Data/Stocks/sbsi.us.txt
# /kaggle/input/Data/Stocks/evc.us.txt
# /kaggle/input/Data/Stocks/mdlz.us.txt
# /kaggle/input/Data/Stocks/enz.us.txt
# /kaggle/input/Data/Stocks/bios.us.txt
# /kaggle/input/Data/Stocks/eacqw.us.txt
# /kaggle/input/Data/Stocks/terp.us.txt
# /kaggle/input/Data/Stocks/ssn.us.txt
# /kaggle/input/Data/Stocks/jw-a.us.txt
# /kaggle/input/Data/Stocks/oacqr.us.txt
# /kaggle/input/Data/Stocks/tusk.us.txt
# /kaggle/input/Data/Stocks/pbbi.us.txt
# /kaggle/input/Data/Stocks/lorl.us.txt
# /kaggle/input/Data/Stocks/giga.us.txt
# /kaggle/input/Data/Stocks/t.us.txt
# /kaggle/input/Data/Stocks/cic-u.us.txt
# /kaggle/input/Data/Stocks/ktov.us.txt
# /kaggle/input/Data/Stocks/soi.us.txt
# /kaggle/input/Data/Stocks/stld.us.txt
# /kaggle/input/Data/Stocks/bkd.us.txt
# /kaggle/input/Data/Stocks/salm.us.txt
# /kaggle/input/Data/Stocks/sti_a.us.txt
# /kaggle/input/Data/Stocks/rt.us.txt
# /kaggle/input/Data/Stocks/amfw.us.txt
# /kaggle/input/Data/Stocks/chh.us.txt
# /kaggle/input/Data/Stocks/amnb.us.txt
# /kaggle/input/Data/Stocks/ainv.us.txt
# /kaggle/input/Data/Stocks/pui.us.txt
# /kaggle/input/Data/Stocks/dnow.us.txt
# /kaggle/input/Data/Stocks/cns.us.txt
# /kaggle/input/Data/Stocks/gslc.us.txt
# /kaggle/input/Data/Stocks/cveo.us.txt
# /kaggle/input/Data/Stocks/mvt.us.txt
# /kaggle/input/Data/Stocks/etfc.us.txt
# /kaggle/input/Data/Stocks/wsfs.us.txt
# /kaggle/input/Data/Stocks/fwp.us.txt
# /kaggle/input/Data/Stocks/lor.us.txt
# /kaggle/input/Data/Stocks/rlgt.us.txt
# /kaggle/input/Data/Stocks/brfs.us.txt
# /kaggle/input/Data/Stocks/corr.us.txt
# /kaggle/input/Data/Stocks/out.us.txt
# /kaggle/input/Data/Stocks/geny.us.txt
# /kaggle/input/Data/Stocks/ifn.us.txt
# /kaggle/input/Data/Stocks/ssw_d.us.txt
# /kaggle/input/Data/Stocks/bku.us.txt
# /kaggle/input/Data/Stocks/ovas.us.txt
# /kaggle/input/Data/Stocks/rvnc.us.txt
# /kaggle/input/Data/Stocks/mitl.us.txt
# /kaggle/input/Data/Stocks/vly_a.us.txt
# /kaggle/input/Data/Stocks/acrx.us.txt
# /kaggle/input/Data/Stocks/etb.us.txt
# /kaggle/input/Data/Stocks/gsew.us.txt
# /kaggle/input/Data/Stocks/tivo.us.txt
# /kaggle/input/Data/Stocks/gabr.us.txt
# /kaggle/input/Data/Stocks/pxus.us.txt
# /kaggle/input/Data/Stocks/dwsn.us.txt
# /kaggle/input/Data/Stocks/cwbc.us.txt

# %% [markdown]
# The next hidden code cells define functions for plotting data. Click on the "Code" button in the published kernel to reveal the hidden code.

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %% [markdown]
# Oh, no! There are no automatic insights available for the file types used in this dataset. As your Kaggle kerneler bot, I'll keep working to fine-tune my hyper-parameters. In the meantime, please feel free to try a different dataset.

# %% [markdown]
# ## Conclusion
# This concludes your starter analysis! To go forward from here, click the blue "Edit Notebook" button at the top of the kernel. This will create a copy of the code and environment for you to edit. Delete, modify, and add code as you please. Happy Kaggling!
